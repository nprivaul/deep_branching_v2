# %% [raw]
# # Imports & basic configuration

# %%
try:
    # always cd to the right directory in google colab
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd "/content/drive/MyDrive/Colab Notebooks/branch_full/deep_branching"
except:
    pass

import math
from scipy import special
import numpy as np
import torch
import matplotlib.pyplot as plt
import time
from branch import Net
# from compare_performance import compare_performance
from branch_NPP23 import Net_NPP23
from galerkin import DGMNet
from bsde import BSDENet
import logging

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# perfect reproducibility is not guaranteed with different version of torch
#
import torchaudio
import torchvision

print(f"torch version: {torch.__version__}")
print(f"torchaudio version: {torchaudio.__version__}")
print(f"torchvision version: {torchvision.__version__}")
# Out:
# torch version: 2.5.1+cu124
# torchaudio version: 2.5.1+cu124
# torchvision version: 0.20.1+cu124

# %%
print("Information of the allocated GPU.")
# !nvidia-smi
# Out:
# Information of the allocated GPU.
# Fri Nov 15 16:55:42 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A4000               Off |   00000000:21:00.0  On |                  Off |
# | 41%   40C    P8             19W /  140W |    3731MiB /  16376MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2549      G   /usr/lib/xorg/Xorg                            421MiB |
# |    0   N/A  N/A      2809      G   /usr/bin/gnome-shell                          413MiB |
# |    0   N/A  N/A      3500      G   ...3/usr/bin/snapd-desktop-integration         44MiB |
# |    0   N/A  N/A      3511      G   /usr/libexec/xdg-desktop-portal-gnome        1875MiB |
# |    0   N/A  N/A      3540      G   ...AAAAAAAACAAAAAAAAAA= --shared-files         72MiB |
# |    0   N/A  N/A     17756      G   ...46ad057035c77b8e0801dd9e381f28b99ed         89MiB |
# |    0   N/A  N/A    475387      G   ...seed-version=20241104-180211.094000         95MiB |
# |    0   N/A  N/A    689523      G   ...irefox/5239/usr/lib/firefox/firefox          0MiB |
# |    0   N/A  N/A    692780      G   ...usr/lib/thunderbird/thunderbird-bin          0MiB |
# |    0   N/A  N/A   1086068      G   ...ures=SpareRendererForSitePerProcess         76MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# performance evaluation for PDE
def compare_performance(
    grid_1d,
    grid_nd,
    grid_with_t,
    t_lo,
    true,
    terminal,
    fname=None,
    debug_mode=False,
    disable_galerkin=False,
    disable_bsde=False,
    disable_branch=False,
    disable_branch_NPP23=False,
    seeds=list(range(10)),
    **kwargs,
):
    x_lo, x_hi = grid_nd.min(), grid_nd.max()
    grid_nd = grid_nd.astype(np.float32)
    grid_with_t = grid_with_t.astype(np.float32)

#    fname = f"{fname}_dim_{grid_nd.shape[0]}" if fname is not None else None
    fname = f"{fname}" if fname is not None else None
    counter = 1

    branch_runtime, branch_l1_error, branch_l2_error, branch_rel_error, branch = (
        [],
        [],
        [],
        [],
        0,
    )
    branch_NPP23_runtime, branch_NPP23_l1_error, branch_NPP23_l2_error, branch_NPP23_rel_error, branch_NPP23 = (
        [],
        [],
        [],
        [],
        0,
    )
    branch_total_runtime = []
    branch_NPP23_fdb_runtime, branch_NPP23_total_runtime = [], []
    dgm_runtime, dgm_l1_error, dgm_l2_error, dgm_rel_error, dgm = [], [], [], [], 0
    bsde_runtime, bsde_l1_error, bsde_l2_error, bsde_rel_error, bsde = [], [], [], [], 0
    for seed in seeds:
        ######### Deep branching method
        if not disable_branch:
            torch.manual_seed(seed)
            print(
                f"#### Starting deep branching method with seed {seed} - {counter} out of {len(seeds)} times"
            )
            start = time.time()
            model = Net(t_lo=t_lo, t_hi=t_hi, x_lo=x_lo, x_hi=x_hi, **kwargs)
            model.train_and_eval(debug_mode)
            branch_total_runtime.append(time.time() - start)
            branch_runtime.append(branch_total_runtime[-1])
            tmp = (
                model(torch.tensor(grid_with_t.T, device=device)).detach().cpu().numpy()
            )
            branch += tmp
            branch_l1_error.append((np.abs(tmp - true)).mean())
            branch_l2_error.append(((tmp - true) ** 2).mean())
            branch_rel_error.append((np.abs(tmp - true) / np.abs(true)).mean())
            print(
                f"Time taken: {branch_runtime[-1]:.0f} seconds; L1 error: {branch_l1_error[-1]:.2E}; L2 error: {branch_l2_error[-1]:.2E}; rel error: {branch_rel_error[-1]:.2E}."
            )
            print(
                f"total runtime: {branch_total_runtime[-1]:.0f} seconds."
            )
            
        ######### NPP23 Deep branching method
        if not disable_branch_NPP23:
            torch.manual_seed(seed)
            print(
                f"#### Starting NPP23 deep branching method with seed {seed} - {counter} out of {len(seeds)} times"
            )
            start = time.time()
            model_NPP23 = Net_NPP23(t_lo=t_lo, t_hi=t_lo, x_lo=x_lo, x_hi=x_hi, **kwargs)
            model_NPP23.train_and_eval(debug_mode)
            branch_NPP23_total_runtime.append(time.time() - start)
            branch_NPP23_fdb_runtime.append(model_NPP23.fdb_runtime)
            branch_NPP23_runtime.append(branch_NPP23_total_runtime[-1] - branch_NPP23_fdb_runtime[-1])
            tmp = (
                model_NPP23(torch.tensor(grid_with_t.T, device=device)).detach().cpu().numpy()
            )
            branch_NPP23 += tmp
            branch_NPP23_l1_error.append((np.abs(tmp - true)).mean())
            branch_NPP23_l2_error.append(((tmp - true) ** 2).mean())
            branch_NPP23_rel_error.append((np.abs(tmp - true) / np.abs(true)).mean())
            print(
                f"Time taken: {branch_NPP23_runtime[-1]:.0f} seconds; L1 error: {branch_NPP23_l1_error[-1]:.2E}; L2 error: {branch_NPP23_l2_error[-1]:.2E}; rel error: {branch_NPP23_rel_error[-1]:.2E}."
            )
            print(
                f"fdb runtime: {branch_NPP23_fdb_runtime[-1]:.0f} seconds; total runtime: {branch_NPP23_total_runtime[-1]:.0f} seconds."
            )

        ######### Deep galerkin method
        if not disable_galerkin:
            torch.manual_seed(seed)
            print(
                f"#### Starting deep galerkin method with seed {seed} - {counter} out of {len(seeds)} times"
            )
            start = time.time()
            model = DGMNet(t_lo=t_lo, t_hi=kwargs["T"], x_lo=x_lo, x_hi=x_hi, **kwargs)
            model.train_and_eval(debug_mode)
            dgm_runtime.append(time.time() - start)
            tmp = (
                model(torch.tensor(grid_with_t.T, device=device)).detach().cpu().numpy()
            )
            dgm += tmp
            dgm_l1_error.append((np.abs(tmp - true)).mean())
            dgm_l2_error.append(((tmp - true) ** 2).mean())
            dgm_rel_error.append((np.abs(tmp - true) / np.abs(true)).mean())
            print(
                f"Time taken: {dgm_runtime[-1]:.0f} seconds; L1 error: {dgm_l1_error[-1]:.2E}; L2 error: {dgm_l2_error[-1]:.2E}; rel error: {dgm_rel_error[-1]:.2E}."
            )

        ######### Deep BSDE method
        if not disable_bsde:
            torch.manual_seed(seed)
            print(
                f"#### Starting deep BSDE method with seed {seed} - {counter} out of {len(seeds)} times"
            )
            start = time.time()
            model = BSDENet(t_lo=t_lo, t_hi=kwargs["T"], x_lo=x_lo, x_hi=x_hi, **kwargs)
            model.train_and_eval(debug_mode)
            bsde_runtime.append(time.time() - start)
            tmp = (
                model(torch.tensor(grid_nd.T, device=device))
                .squeeze(-1)
                .detach()
                .cpu()
                .numpy()
            )
            bsde += tmp
            bsde_l1_error.append((np.abs(tmp - true)).mean())
            bsde_l2_error.append(((tmp - true) ** 2).mean())
            bsde_rel_error.append((np.abs(tmp - true) / np.abs(true)).mean())
            print(
                f"Time taken: {bsde_runtime[-1]:.0f} seconds; L1 error: {bsde_l1_error[-1]:.2E}; L2 error: {bsde_l2_error[-1]:.2E}; rel error: {bsde_rel_error[-1]:.2E}."
            )

        print("\n")
        counter += 1

    # Plot
    f = plt.figure()
    plt.plot(grid_1d, true, label="True solution")
    plt.plot(grid_1d, terminal, label="Terminal condition")
    # save into csv
    if fname is not None:
        plt_data = np.stack((grid_1d, true, terminal), axis=-1)
        plt_header = "x, true, terminal"

    if not disable_branch:
        branch /= len(seeds)
        branch_runtime, branch_l1_error, branch_l2_error, branch_rel_error = (
            np.array(branch_runtime),
            np.array(branch_l1_error),
            np.array(branch_l2_error),
            np.array(branch_rel_error),
        )
        branch_total_runtime = np.array(branch_total_runtime)
        print("\n")
        print("######## Summary for deep branching method")
        print(f"runtime:        {branch_runtime.mean():.0f}")
        print(f"total runtime:  {branch_total_runtime.mean():.0f}")
        print(f"mean L1 error:  {branch_l1_error.mean():.2E}")
        print(f"std L1 error:   {branch_l1_error.std():.2E}")
        print(f"mean L2 error:  {branch_l2_error.mean():.2E}")
        print(f"std L2 error:   {branch_l2_error.std():.2E}")
        print(f"mean rel error: {branch_rel_error.mean():.2E}")
        print(f"std rel error:  {branch_rel_error.std():.2E}")
        # Plot
        plt.plot(grid_1d, branch, label="Deep branching")
        # save into csv
        if fname is not None:
            plt_data = np.concatenate(
                (plt_data, np.expand_dims(branch, axis=-1)), axis=-1
            )
            plt_header += ", branch"
            data = np.stack(
                (branch_runtime, branch_l1_error, branch_l2_error, branch_rel_error),
                axis=-1,
            )
            np.savetxt(
                "log/branch_" + fname + ".csv",
                data,
                delimiter=",",
                header="runtime,l1_error,l2_error,rel_error",
                comments="",
            )
            
    if not disable_branch_NPP23:
        branch_NPP23 /= len(seeds)
        branch_NPP23_runtime, branch_NPP23_l1_error, branch_NPP23_l2_error, branch_NPP23_rel_error = (
            np.array(branch_NPP23_runtime),
            np.array(branch_NPP23_l1_error),
            np.array(branch_NPP23_l2_error),
            np.array(branch_NPP23_rel_error),
        )
        branch_NPP23_fdb_runtime, branch_NPP23_total_runtime = np.array(
            branch_NPP23_fdb_runtime
        ), np.array(branch_NPP23_total_runtime)
        print("\n")
        print("######## Summary for NPP23 deep branching method")
        print(f"runtime:        {branch_NPP23_runtime.mean():.0f}")
        print(f"fdb runtime:    {branch_NPP23_fdb_runtime.mean():.0f}")
        print(f"total runtime:  {branch_NPP23_total_runtime.mean():.0f}")
        print(f"mean L1 error:  {branch_NPP23_l1_error.mean():.2E}")
        print(f"std L1 error:   {branch_NPP23_l1_error.std():.2E}")
        print(f"mean L2 error:  {branch_NPP23_l2_error.mean():.2E}")
        print(f"std L2 error:   {branch_NPP23_l2_error.std():.2E}")
        print(f"mean rel error: {branch_NPP23_rel_error.mean():.2E}")
        print(f"std rel error:  {branch_NPP23_rel_error.std():.2E}")
        # Plot
        plt.plot(grid_1d, branch_NPP23, label="NPP23 Deep branching")
        # save into csv
        if fname is not None:
            plt_data = np.concatenate(
                (plt_data, np.expand_dims(branch_NPP23, axis=-1)), axis=-1
            )
            plt_header += ", branch"
            data = np.stack(
                (branch_NPP23_runtime, branch_NPP23_l1_error, branch_NPP23_l2_error, branch_NPP23_rel_error),
                axis=-1,
            )
            np.savetxt(
                "log/branch_" + fname + ".csv",
                data,
                delimiter=",",
                header="runtime,l1_error,l2_error,rel_error",
                comments="",
            )

    if not disable_galerkin:
        dgm /= len(seeds)
        dgm_runtime, dgm_l1_error, dgm_l2_error, dgm_rel_error = (
            np.array(dgm_runtime),
            np.array(dgm_l1_error),
            np.array(dgm_l2_error),
            np.array(dgm_rel_error),
        )
        print("\n")
        print("######## Summary for deep galerkin method")
        print(f"runtime:        {dgm_runtime.mean():.0f}")
        print(f"mean L1 error:  {dgm_l1_error.mean():.2E}")
        print(f"std L1 error:   {dgm_l1_error.std():.2E}")
        print(f"mean L2 error:  {dgm_l2_error.mean():.2E}")
        print(f"std L2 error:   {dgm_l2_error.std():.2E}")
        print(f"mean rel error: {dgm_rel_error.mean():.2E}")
        print(f"std rel error:  {dgm_rel_error.std():.2E}")
        # Plot
        plt.plot(grid_1d, dgm, label="Deep Galerkin")
        # save into csv
        if fname is not None:
            plt_data = np.concatenate((plt_data, np.expand_dims(dgm, axis=-1)), axis=-1)
            plt_header += ", dgm"
            data = np.stack(
                (dgm_runtime, dgm_l1_error, dgm_l2_error, dgm_rel_error), axis=-1
            )
            np.savetxt(
                "log/dgm_" + fname + ".csv",
                data,
                delimiter=",",
                header="runtime,l1_error,l2_error,rel_error",
                comments="",
            )

    ######### Deep BSDE method
    if not disable_bsde:
        bsde /= len(seeds)
        bsde_runtime, bsde_l1_error, bsde_l2_error, bsde_rel_error = (
            np.array(bsde_runtime),
            np.array(bsde_l1_error),
            np.array(bsde_l2_error),
            np.array(bsde_rel_error),
        )
        print("\n")
        print("######## Summary for deep BSDE method")
        print(f"runtime:        {bsde_runtime.mean():.0f}")
        print(f"mean L1 error:  {bsde_l1_error.mean():.2E}")
        print(f"std L1 error:   {bsde_l1_error.std():.2E}")
        print(f"mean L2 error:  {bsde_l2_error.mean():.2E}")
        print(f"std L2 error:   {bsde_l2_error.std():.2E}")
        print(f"mean rel error: {bsde_rel_error.mean():.2E}")
        print(f"std rel error:  {bsde_rel_error.std():.2E}")
        # Plot
        plt.plot(grid_1d, bsde, label="Deep BSDE")
        # save into csv
        if fname is not None:
            plt_data = np.concatenate(
                (plt_data, np.expand_dims(bsde, axis=-1)), axis=-1
            )
            plt_header += ", bsde"
            data = np.stack(
                (bsde_runtime, bsde_l1_error, bsde_l2_error, bsde_rel_error), axis=-1
            )
            np.savetxt(
                "log/bsde_" + fname + ".csv",
                data,
                delimiter=",",
                header="runtime,l1_error,l2_error,rel_error",
                comments="",
            )

    plt.legend()
    plt.show()
    fname = f"{fname}_dim_{dim}" if fname is not None else f"demo_dim_{dim}"
    plt.savefig(f"plot/{'comparison' if fname is None else fname}.pdf")
    if fname is not None:
        np.savetxt(
            "log/plt_" + fname + ".csv", plt_data, delimiter=",", header=plt_header, comments=""
        )

# %% [markdown]
# ## Exponential nonlinearity

# %%
# function definition
fixed_dim, dim = 0, 1

problem_name = f"exp_dim_{dim}"

# function definition
deriv_map = np.array([0] * dim).reshape(-1, dim)
def f_example2(y):
    """
    idx 0 -> no deriv
    """
    return 6 + 4*torch.exp(-y) - 10*torch.exp(-y/2) + torch.exp(y/2) - torch.exp(y) # y - y ** 3

def f_example(y):
    """
    idx 0 -> no deriv
    """
    return 6 + 4*torch.exp(-y[0]) - 10*torch.exp(-y[0]/2) + torch.exp(y[0]/2) - torch.exp(y[0]) # y - y ** 3

deriv_map = np.array([0]).reshape(-1, 1)

dgm_deriv_map = np.array([0, 1, 2]).reshape(-1, 1)

def dgm_f_example(y):
    """
    idx 0 -> no deriv
    idx 1 -> first deriv
    idx 2 -> second deriv
    """
    return .5 * y[2] + 6 + 4*torch.exp(-y[0]) - 10*torch.exp(-y[0]/2) + torch.exp(y[0]/2) - torch.exp(y[0]) # y[0] - y[0] ** 3

def phi_example(x):
    return 2*torch.log(1+1/(1+torch.exp(x.sum(dim=0) / math.sqrt(dim)))) # -0.5 - 0.5 * torch.nn.Tanh()(-.5 * x.sum(dim=0) / math.sqrt(dim))

def exact_example(t, x, T):
    return 2*np.log(1+1/(1+np.exp(x.sum(axis=0) / math.sqrt(dim)-(T-t)))) # -0.5 - 0.5 * np.tanh(-.5*x.sum(axis=0)/math.sqrt(dim) + 3*(T-t)/4)

t_lo, t_hi, x_lo, x_hi, n = 0., 0., -4., 4., 1
grid = np.linspace(x_lo, x_hi, 100)
grid_d_dim = np.expand_dims(grid, axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

T = .5
true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # disable_bsde=True, disable_galerkin=True, verbose=True, debug_mode=True,
                    T=T, device=device, epochs=3000, fname="exp_example",
                    branch_nb_states=10000, branch_nb_path_per_state=1000, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=1000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 109 seconds; L1 error: 2.33E-03; L2 error: 9.90E-06; rel error: 3.14E-03.
# total runtime: 109 seconds.
# #### Starting NPP23 deep branching method with seed 0 - 1 out of 10 times
# Time taken: 101 seconds; L1 error: 1.21E-03; L2 error: 2.21E-06; rel error: 1.74E-03.
# fdb runtime: 0 seconds; total runtime: 101 seconds.
# #### Starting deep galerkin method with seed 0 - 1 out of 10 times
# Time taken: 71 seconds; L1 error: 7.58E-04; L2 error: 1.12E-06; rel error: 3.54E-03.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 95 seconds; L1 error: 2.77E-03; L2 error: 1.48E-05; rel error: 4.83E-03.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 111 seconds; L1 error: 3.99E-03; L2 error: 3.83E-05; rel error: 5.42E-03.
# total runtime: 111 seconds.
# #### Starting NPP23 deep branching method with seed 1 - 2 out of 10 times
# Time taken: 96 seconds; L1 error: 1.42E-03; L2 error: 4.43E-06; rel error: 2.32E-03.
# fdb runtime: 0 seconds; total runtime: 96 seconds.
# #### Starting deep galerkin method with seed 1 - 2 out of 10 times
# Time taken: 73 seconds; L1 error: 2.31E-04; L2 error: 9.42E-08; rel error: 7.20E-04.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 99 seconds; L1 error: 2.26E-03; L2 error: 6.68E-06; rel error: 5.33E-03.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 104 seconds; L1 error: 3.52E-03; L2 error: 3.08E-05; rel error: 4.68E-03.
# total runtime: 104 seconds.
# #### Starting NPP23 deep branching method with seed 2 - 3 out of 10 times
# Time taken: 98 seconds; L1 error: 1.33E-03; L2 error: 3.86E-06; rel error: 1.96E-03.
# fdb runtime: 0 seconds; total runtime: 98 seconds.
# #### Starting deep galerkin method with seed 2 - 3 out of 10 times
# Time taken: 72 seconds; L1 error: 3.01E-04; L2 error: 1.38E-07; rel error: 1.29E-03.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 87 seconds; L1 error: 4.31E-03; L2 error: 3.25E-05; rel error: 9.63E-03.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 106 seconds; L1 error: 2.85E-03; L2 error: 1.91E-05; rel error: 3.76E-03.
# total runtime: 106 seconds.
# #### Starting NPP23 deep branching method with seed 3 - 4 out of 10 times
# Time taken: 96 seconds; L1 error: 2.33E-03; L2 error: 1.01E-05; rel error: 2.83E-03.
# fdb runtime: 0 seconds; total runtime: 96 seconds.
# #### Starting deep galerkin method with seed 3 - 4 out of 10 times
# Time taken: 75 seconds; L1 error: 2.78E-04; L2 error: 9.38E-08; rel error: 8.38E-04.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 103 seconds; L1 error: 3.69E-03; L2 error: 1.81E-05; rel error: 9.85E-03.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 109 seconds; L1 error: 2.69E-03; L2 error: 1.54E-05; rel error: 3.68E-03.
# total runtime: 109 seconds.
# #### Starting NPP23 deep branching method with seed 4 - 5 out of 10 times
# Time taken: 90 seconds; L1 error: 1.85E-03; L2 error: 9.31E-06; rel error: 2.22E-03.
# fdb runtime: 0 seconds; total runtime: 90 seconds.
# #### Starting deep galerkin method with seed 4 - 5 out of 10 times
# Time taken: 69 seconds; L1 error: 3.78E-04; L2 error: 2.79E-07; rel error: 1.61E-03.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 94 seconds; L1 error: 3.02E-03; L2 error: 1.23E-05; rel error: 7.98E-03.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 117 seconds; L1 error: 2.39E-03; L2 error: 2.54E-05; rel error: 3.44E-03.
# total runtime: 117 seconds.
# #### Starting NPP23 deep branching method with seed 5 - 6 out of 10 times
# Time taken: 106 seconds; L1 error: 1.61E-03; L2 error: 5.48E-06; rel error: 2.90E-03.
# fdb runtime: 0 seconds; total runtime: 106 seconds.
# #### Starting deep galerkin method with seed 5 - 6 out of 10 times
# Time taken: 79 seconds; L1 error: 3.33E-04; L2 error: 1.58E-07; rel error: 1.28E-03.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 95 seconds; L1 error: 3.90E-03; L2 error: 2.20E-05; rel error: 1.24E-02.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 111 seconds; L1 error: 2.20E-03; L2 error: 9.38E-06; rel error: 2.82E-03.
# total runtime: 111 seconds.
# #### Starting NPP23 deep branching method with seed 6 - 7 out of 10 times
# Time taken: 93 seconds; L1 error: 1.17E-03; L2 error: 2.92E-06; rel error: 1.72E-03.
# fdb runtime: 0 seconds; total runtime: 93 seconds.
# #### Starting deep galerkin method with seed 6 - 7 out of 10 times
# Time taken: 76 seconds; L1 error: 6.02E-04; L2 error: 6.25E-07; rel error: 2.74E-03.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 90 seconds; L1 error: 4.54E-03; L2 error: 4.11E-05; rel error: 1.34E-02.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 111 seconds; L1 error: 3.35E-03; L2 error: 2.77E-05; rel error: 4.91E-03.
# total runtime: 111 seconds.
# #### Starting NPP23 deep branching method with seed 7 - 8 out of 10 times
# Time taken: 94 seconds; L1 error: 1.43E-03; L2 error: 3.11E-06; rel error: 2.38E-03.
# fdb runtime: 0 seconds; total runtime: 94 seconds.
# #### Starting deep galerkin method with seed 7 - 8 out of 10 times
# Time taken: 79 seconds; L1 error: 8.57E-04; L2 error: 9.56E-07; rel error: 2.87E-03.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 90 seconds; L1 error: 4.59E-03; L2 error: 4.17E-05; rel error: 1.29E-02.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 112 seconds; L1 error: 3.02E-03; L2 error: 2.31E-05; rel error: 4.16E-03.
# total runtime: 112 seconds.
# #### Starting NPP23 deep branching method with seed 8 - 9 out of 10 times
# Time taken: 96 seconds; L1 error: 1.98E-03; L2 error: 7.83E-06; rel error: 2.85E-03.
# fdb runtime: 0 seconds; total runtime: 96 seconds.
# #### Starting deep galerkin method with seed 8 - 9 out of 10 times
# Time taken: 82 seconds; L1 error: 6.13E-04; L2 error: 5.43E-07; rel error: 1.90E-03.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 100 seconds; L1 error: 5.11E-03; L2 error: 3.55E-05; rel error: 1.13E-02.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 105 seconds; L1 error: 2.87E-03; L2 error: 1.52E-05; rel error: 5.18E-03.
# total runtime: 105 seconds.
# #### Starting NPP23 deep branching method with seed 9 - 10 out of 10 times
# Time taken: 93 seconds; L1 error: 1.80E-03; L2 error: 6.85E-06; rel error: 3.54E-03.
# fdb runtime: 0 seconds; total runtime: 93 seconds.
# #### Starting deep galerkin method with seed 9 - 10 out of 10 times
# Time taken: 74 seconds; L1 error: 3.43E-04; L2 error: 2.13E-07; rel error: 1.56E-03.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 107 seconds; L1 error: 5.97E-03; L2 error: 5.00E-05; rel error: 1.28E-02.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        110
# total runtime:  110
# mean L1 error:  2.92E-03
# std L1 error:   5.39E-04
# mean L2 error:  2.14E-05
# std L2 error:   8.89E-06
# mean rel error: 4.12E-03
# std rel error:  8.48E-04
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        96
# fdb runtime:    0
# total runtime:  96
# mean L1 error:  1.61E-03
# std L1 error:   3.52E-04
# mean L2 error:  5.61E-06
# std L2 error:   2.64E-06
# mean rel error: 2.45E-03
# std rel error:  5.50E-04
#
#
# ######## Summary for deep galerkin method
# runtime:        75
# mean L1 error:  4.69E-04
# std L1 error:   2.09E-04
# mean L2 error:  4.22E-07
# std L2 error:   3.55E-07
# mean rel error: 1.83E-03
# std rel error:  8.82E-04
#
#
# ######## Summary for deep BSDE method
# runtime:        96
# mean L1 error:  4.02E-03
# std L1 error:   1.07E-03
# mean L2 error:  2.75E-05
# std L2 error:   1.39E-05
# mean rel error: 1.00E-02
# std rel error:  2.96E-03

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # disable_bsde=True, disable_galerkin=True, verbose=True, debug_mode=True,
                    T=T, device=device, epochs=3000, fname="exp_example",
                    branch_nb_states=10000, branch_nb_path_per_state=10, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=1, #-math.log(.95)/T,                    
                    bsde_nb_states=1000, bsde_nb_time_intervals=4,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 81 seconds; L1 error: 6.92E-03; L2 error: 9.07E-05; rel error: 7.29E-03.
# fdb runtime: 0 seconds; total runtime: 81 seconds.
# #### Starting NPP23 deep branching method with seed 0 - 1 out of 10 times
# Time taken: 148 seconds; L1 error: 7.20E-03; L2 error: 1.04E-04; rel error: 7.84E-03.
# fdb runtime: 0 seconds; total runtime: 148 seconds.
# #### Starting deep galerkin method with seed 0 - 1 out of 10 times
# Time taken: 77 seconds; L1 error: 7.58E-04; L2 error: 1.12E-06; rel error: 3.54E-03.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 93 seconds; L1 error: 2.77E-03; L2 error: 1.48E-05; rel error: 4.83E-03.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 81 seconds; L1 error: 4.91E-03; L2 error: 4.66E-05; rel error: 5.62E-03.
# fdb runtime: 0 seconds; total runtime: 81 seconds.
# #### Starting NPP23 deep branching method with seed 1 - 2 out of 10 times
# Time taken: 109 seconds; L1 error: 5.17E-03; L2 error: 4.67E-05; rel error: 6.60E-03.
# fdb runtime: 0 seconds; total runtime: 109 seconds.
# #### Starting deep galerkin method with seed 1 - 2 out of 10 times
# Time taken: 59 seconds; L1 error: 2.31E-04; L2 error: 9.42E-08; rel error: 7.20E-04.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 98 seconds; L1 error: 2.26E-03; L2 error: 6.68E-06; rel error: 5.33E-03.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 74 seconds; L1 error: 5.92E-03; L2 error: 5.48E-05; rel error: 8.02E-03.
# fdb runtime: 0 seconds; total runtime: 74 seconds.
# #### Starting NPP23 deep branching method with seed 2 - 3 out of 10 times
# Time taken: 100 seconds; L1 error: 6.25E-03; L2 error: 8.63E-05; rel error: 7.29E-03.
# fdb runtime: 0 seconds; total runtime: 100 seconds.
# #### Starting deep galerkin method with seed 2 - 3 out of 10 times
# Time taken: 79 seconds; L1 error: 3.01E-04; L2 error: 1.38E-07; rel error: 1.29E-03.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 104 seconds; L1 error: 4.31E-03; L2 error: 3.25E-05; rel error: 9.63E-03.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 71 seconds; L1 error: 7.83E-03; L2 error: 1.45E-04; rel error: 8.36E-03.
# fdb runtime: 0 seconds; total runtime: 71 seconds.
# #### Starting NPP23 deep branching method with seed 3 - 4 out of 10 times
# Time taken: 108 seconds; L1 error: 4.59E-03; L2 error: 4.29E-05; rel error: 5.13E-03.
# fdb runtime: 0 seconds; total runtime: 108 seconds.
# #### Starting deep galerkin method with seed 3 - 4 out of 10 times
# Time taken: 76 seconds; L1 error: 2.78E-04; L2 error: 9.38E-08; rel error: 8.38E-04.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 105 seconds; L1 error: 3.69E-03; L2 error: 1.81E-05; rel error: 9.85E-03.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 75 seconds; L1 error: 7.56E-03; L2 error: 9.76E-05; rel error: 1.00E-02.
# fdb runtime: 0 seconds; total runtime: 75 seconds.
# #### Starting NPP23 deep branching method with seed 4 - 5 out of 10 times
# Time taken: 101 seconds; L1 error: 8.34E-03; L2 error: 1.23E-04; rel error: 1.01E-02.
# fdb runtime: 0 seconds; total runtime: 101 seconds.
# #### Starting deep galerkin method with seed 4 - 5 out of 10 times
# Time taken: 74 seconds; L1 error: 3.78E-04; L2 error: 2.79E-07; rel error: 1.61E-03.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 113 seconds; L1 error: 3.02E-03; L2 error: 1.23E-05; rel error: 7.98E-03.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 85 seconds; L1 error: 6.97E-03; L2 error: 6.89E-05; rel error: 9.98E-03.
# fdb runtime: 0 seconds; total runtime: 85 seconds.
# #### Starting NPP23 deep branching method with seed 5 - 6 out of 10 times
# Time taken: 106 seconds; L1 error: 6.35E-03; L2 error: 7.19E-05; rel error: 7.28E-03.
# fdb runtime: 0 seconds; total runtime: 106 seconds.
# #### Starting deep galerkin method with seed 5 - 6 out of 10 times
# Time taken: 74 seconds; L1 error: 3.33E-04; L2 error: 1.58E-07; rel error: 1.28E-03.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 93 seconds; L1 error: 3.90E-03; L2 error: 2.20E-05; rel error: 1.24E-02.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 79 seconds; L1 error: 4.87E-03; L2 error: 4.62E-05; rel error: 6.05E-03.
# fdb runtime: 0 seconds; total runtime: 79 seconds.
# #### Starting NPP23 deep branching method with seed 6 - 7 out of 10 times
# Time taken: 107 seconds; L1 error: 6.86E-03; L2 error: 8.85E-05; rel error: 8.89E-03.
# fdb runtime: 0 seconds; total runtime: 107 seconds.
# #### Starting deep galerkin method with seed 6 - 7 out of 10 times
# Time taken: 86 seconds; L1 error: 6.02E-04; L2 error: 6.25E-07; rel error: 2.74E-03.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 105 seconds; L1 error: 4.54E-03; L2 error: 4.11E-05; rel error: 1.34E-02.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 69 seconds; L1 error: 7.48E-03; L2 error: 1.13E-04; rel error: 8.47E-03.
# fdb runtime: 0 seconds; total runtime: 69 seconds.
# #### Starting NPP23 deep branching method with seed 7 - 8 out of 10 times
# Time taken: 107 seconds; L1 error: 7.42E-03; L2 error: 9.11E-05; rel error: 8.92E-03.
# fdb runtime: 0 seconds; total runtime: 107 seconds.
# #### Starting deep galerkin method with seed 7 - 8 out of 10 times
# Time taken: 90 seconds; L1 error: 8.57E-04; L2 error: 9.56E-07; rel error: 2.87E-03.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 99 seconds; L1 error: 4.59E-03; L2 error: 4.17E-05; rel error: 1.29E-02.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 75 seconds; L1 error: 5.14E-03; L2 error: 4.68E-05; rel error: 5.92E-03.
# fdb runtime: 0 seconds; total runtime: 75 seconds.
# #### Starting NPP23 deep branching method with seed 8 - 9 out of 10 times
# Time taken: 106 seconds; L1 error: 4.76E-03; L2 error: 3.75E-05; rel error: 7.99E-03.
# fdb runtime: 0 seconds; total runtime: 106 seconds.
# #### Starting deep galerkin method with seed 8 - 9 out of 10 times
# Time taken: 70 seconds; L1 error: 6.13E-04; L2 error: 5.43E-07; rel error: 1.90E-03.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 79 seconds; L1 error: 5.11E-03; L2 error: 3.55E-05; rel error: 1.13E-02.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 78 seconds; L1 error: 6.76E-03; L2 error: 1.01E-04; rel error: 8.28E-03.
# fdb runtime: 0 seconds; total runtime: 78 seconds.
# #### Starting NPP23 deep branching method with seed 9 - 10 out of 10 times
# Time taken: 106 seconds; L1 error: 6.24E-03; L2 error: 7.24E-05; rel error: 7.70E-03.
# fdb runtime: 0 seconds; total runtime: 106 seconds.
# #### Starting deep galerkin method with seed 9 - 10 out of 10 times
# Time taken: 71 seconds; L1 error: 3.43E-04; L2 error: 2.13E-07; rel error: 1.56E-03.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 105 seconds; L1 error: 5.97E-03; L2 error: 5.00E-05; rel error: 1.28E-02.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        77
# fdb runtime:    0
# total runtime:  77
# mean L1 error:  6.43E-03
# std L1 error:   1.08E-03
# mean L2 error:  8.11E-05
# std L2 error:   3.21E-05
# mean rel error: 7.80E-03
# std rel error:  1.49E-03
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        110
# fdb runtime:    0
# total runtime:  110
# mean L1 error:  6.32E-03
# std L1 error:   1.15E-03
# mean L2 error:  7.63E-05
# std L2 error:   2.62E-05
# mean rel error: 7.77E-03
# std rel error:  1.29E-03
#
#
# ######## Summary for deep galerkin method
# runtime:        76
# mean L1 error:  4.69E-04
# std L1 error:   2.09E-04
# mean L2 error:  4.22E-07
# std L2 error:   3.55E-07
# mean rel error: 1.83E-03
# std rel error:  8.82E-04
#
#
# ######## Summary for deep BSDE method
# runtime:        99
# mean L1 error:  4.02E-03
# std L1 error:   1.07E-03
# mean L2 error:  2.75E-05
# std L2 error:   1.39E-05
# mean rel error: 1.00E-02
# std rel error:  2.96E-03

# %%
fixed_dim, dim = 0, 10

# function definition
deriv_map = np.array([0] * dim).reshape(-1, dim)
def f_example2(y):
    """
    idx 0 -> no deriv
    """
    return 6 + 4 * torch.exp(-y) - 10 * torch.exp(- y / 2) + torch.exp( y / 2) - torch.exp( y )

def f_example(y):
    """
    idx 0 -> no deriv
    """
    return 6 + 4 * torch.exp(-y[0]) - 10 * torch.exp(- y[0] / 2) + torch.exp( y[0] / 2) - torch.exp( y[0] )

dgm_deriv_map = np.concatenate((deriv_map, 2 * np.identity(dim)), axis=0)
def dgm_f_example(y):
    """
    idx 0      -> no deriv
    idx 1 to n -> second deriv
    """
    return .5 * y[1:].sum(axis=0) + 6 + 4 * torch.exp(-y[0]) - 10 * torch.exp(- y[0] / 2) + torch.exp( y[0] / 2) - torch.exp( y[0] ) 

def phi_example(x):
    return 2* torch.log(1 + 1 / ( 1 + torch.exp(x.sum(dim=0) / math.sqrt(dim) )))

def exact_example(t, x, T):
    return 2*np.log(1 + 1/(1 + np.exp(x.sum(axis=0)/np.sqrt(dim) - (T - t))))

t_lo, x_lo, x_hi, n = 0., -8., 8., 0
grid = np.linspace(x_lo, x_hi, 100)
x_mid = (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

T = .5
true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # verbose=True, debug_mode=True, 
                    # disable_branch=True, disable_branch_NPP23=True, disable_galerkin=True, disable_bsde=True,
                    T=T, device=device, epochs=3000, fname="exp_example",
                    branch_nb_states=10000, branch_nb_path_per_state=2000, branch_nb_states_per_batch=1, 
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=100000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 303 seconds; L1 error: 3.29E-03; L2 error: 1.36E-05; rel error: 4.42E-03.
# total runtime: 303 seconds.
# #### Starting NPP23 deep branching method with seed 0 - 1 out of 10 times
# Time taken: 223 seconds; L1 error: 2.70E-03; L2 error: 9.02E-06; rel error: 3.42E-03.
# fdb runtime: 0 seconds; total runtime: 223 seconds.
# #### Starting deep galerkin method with seed 0 - 1 out of 10 times
# Time taken: 229 seconds; L1 error: 1.65E-02; L2 error: 3.20E-04; rel error: 2.47E-02.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 124 seconds; L1 error: 3.76E-03; L2 error: 1.70E-05; rel error: 5.71E-03.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 296 seconds; L1 error: 2.14E-03; L2 error: 6.56E-06; rel error: 3.01E-03.
# total runtime: 296 seconds.
# #### Starting NPP23 deep branching method with seed 1 - 2 out of 10 times
# Time taken: 236 seconds; L1 error: 2.65E-03; L2 error: 1.14E-05; rel error: 3.34E-03.
# fdb runtime: 0 seconds; total runtime: 236 seconds.
# #### Starting deep galerkin method with seed 1 - 2 out of 10 times
# Time taken: 230 seconds; L1 error: 1.36E-02; L2 error: 2.97E-04; rel error: 1.64E-02.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 124 seconds; L1 error: 3.55E-03; L2 error: 1.87E-05; rel error: 5.34E-03.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 291 seconds; L1 error: 2.34E-03; L2 error: 7.45E-06; rel error: 2.57E-03.
# total runtime: 291 seconds.
# #### Starting NPP23 deep branching method with seed 2 - 3 out of 10 times
# Time taken: 227 seconds; L1 error: 1.72E-03; L2 error: 5.69E-06; rel error: 2.09E-03.
# fdb runtime: 0 seconds; total runtime: 227 seconds.
# #### Starting deep galerkin method with seed 2 - 3 out of 10 times
# Time taken: 232 seconds; L1 error: 1.06E-02; L2 error: 1.28E-04; rel error: 1.56E-02.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 124 seconds; L1 error: 3.84E-03; L2 error: 2.46E-05; rel error: 6.33E-03.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 291 seconds; L1 error: 3.14E-03; L2 error: 1.24E-05; rel error: 4.08E-03.
# total runtime: 291 seconds.
# #### Starting NPP23 deep branching method with seed 3 - 4 out of 10 times
# Time taken: 235 seconds; L1 error: 2.50E-03; L2 error: 8.01E-06; rel error: 3.20E-03.
# fdb runtime: 0 seconds; total runtime: 235 seconds.
# #### Starting deep galerkin method with seed 3 - 4 out of 10 times
# Time taken: 229 seconds; L1 error: 1.07E-02; L2 error: 1.62E-04; rel error: 1.26E-02.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 124 seconds; L1 error: 3.60E-03; L2 error: 1.89E-05; rel error: 6.14E-03.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 285 seconds; L1 error: 2.19E-03; L2 error: 7.01E-06; rel error: 2.64E-03.
# total runtime: 285 seconds.
# #### Starting NPP23 deep branching method with seed 4 - 5 out of 10 times
# Time taken: 235 seconds; L1 error: 2.70E-03; L2 error: 1.17E-05; rel error: 3.31E-03.
# fdb runtime: 0 seconds; total runtime: 235 seconds.
# #### Starting deep galerkin method with seed 4 - 5 out of 10 times
# Time taken: 226 seconds; L1 error: 2.05E-02; L2 error: 5.17E-04; rel error: 2.48E-02.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 124 seconds; L1 error: 4.16E-03; L2 error: 2.17E-05; rel error: 6.52E-03.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 288 seconds; L1 error: 1.71E-03; L2 error: 4.99E-06; rel error: 2.17E-03.
# total runtime: 288 seconds.
# #### Starting NPP23 deep branching method with seed 5 - 6 out of 10 times
# Time taken: 228 seconds; L1 error: 1.67E-03; L2 error: 6.24E-06; rel error: 2.16E-03.
# fdb runtime: 0 seconds; total runtime: 228 seconds.
# #### Starting deep galerkin method with seed 5 - 6 out of 10 times
# Time taken: 235 seconds; L1 error: 1.08E-02; L2 error: 1.89E-04; rel error: 1.11E-02.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 124 seconds; L1 error: 5.19E-03; L2 error: 4.22E-05; rel error: 8.99E-03.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 295 seconds; L1 error: 2.07E-03; L2 error: 7.01E-06; rel error: 2.63E-03.
# total runtime: 295 seconds.
# #### Starting NPP23 deep branching method with seed 6 - 7 out of 10 times
# Time taken: 229 seconds; L1 error: 1.73E-03; L2 error: 6.69E-06; rel error: 1.76E-03.
# fdb runtime: 0 seconds; total runtime: 229 seconds.
# #### Starting deep galerkin method with seed 6 - 7 out of 10 times
# Time taken: 247 seconds; L1 error: 8.16E-03; L2 error: 9.40E-05; rel error: 9.14E-03.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 124 seconds; L1 error: 4.03E-03; L2 error: 2.31E-05; rel error: 6.40E-03.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 298 seconds; L1 error: 1.60E-03; L2 error: 4.42E-06; rel error: 1.78E-03.
# total runtime: 298 seconds.
# #### Starting NPP23 deep branching method with seed 7 - 8 out of 10 times
# Time taken: 229 seconds; L1 error: 2.31E-03; L2 error: 9.15E-06; rel error: 2.85E-03.
# fdb runtime: 0 seconds; total runtime: 229 seconds.
# #### Starting deep galerkin method with seed 7 - 8 out of 10 times
# Time taken: 238 seconds; L1 error: 6.78E-02; L2 error: 5.34E-03; rel error: 7.75E-02.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 124 seconds; L1 error: 4.63E-03; L2 error: 3.06E-05; rel error: 7.50E-03.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 296 seconds; L1 error: 2.78E-03; L2 error: 1.05E-05; rel error: 3.35E-03.
# total runtime: 296 seconds.
# #### Starting NPP23 deep branching method with seed 8 - 9 out of 10 times
# Time taken: 225 seconds; L1 error: 2.00E-03; L2 error: 7.75E-06; rel error: 2.38E-03.
# fdb runtime: 0 seconds; total runtime: 225 seconds.
# #### Starting deep galerkin method with seed 8 - 9 out of 10 times
# Time taken: 227 seconds; L1 error: 1.39E-02; L2 error: 2.89E-04; rel error: 1.99E-02.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 125 seconds; L1 error: 3.80E-03; L2 error: 1.94E-05; rel error: 6.20E-03.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 311 seconds; L1 error: 2.61E-03; L2 error: 9.34E-06; rel error: 3.42E-03.
# total runtime: 311 seconds.
# #### Starting NPP23 deep branching method with seed 9 - 10 out of 10 times
# Time taken: 240 seconds; L1 error: 2.14E-03; L2 error: 7.28E-06; rel error: 2.82E-03.
# fdb runtime: 0 seconds; total runtime: 240 seconds.
# #### Starting deep galerkin method with seed 9 - 10 out of 10 times
# Time taken: 234 seconds; L1 error: 3.25E-02; L2 error: 1.20E-03; rel error: 5.23E-02.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 130 seconds; L1 error: 3.70E-03; L2 error: 1.70E-05; rel error: 5.23E-03.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        295
# total runtime:  295
# mean L1 error:  2.39E-03
# std L1 error:   5.34E-04
# mean L2 error:  8.33E-06
# std L2 error:   2.90E-06
# mean rel error: 3.01E-03
# std rel error:  7.81E-04
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        231
# fdb runtime:    0
# total runtime:  231
# mean L1 error:  2.21E-03
# std L1 error:   3.97E-04
# mean L2 error:  8.29E-06
# std L2 error:   1.94E-06
# mean rel error: 2.73E-03
# std rel error:  5.70E-04
#
#
# ######## Summary for deep galerkin method
# runtime:        233
# mean L1 error:  2.05E-02
# std L1 error:   1.71E-02
# mean L2 error:  8.54E-04
# std L2 error:   1.53E-03
# mean rel error: 2.64E-02
# std rel error:  2.07E-02
#
#
# ######## Summary for deep BSDE method
# runtime:        125
# mean L1 error:  4.02E-03
# std L1 error:   4.91E-04
# mean L2 error:  2.33E-05
# std L2 error:   7.42E-06
# mean rel error: 6.44E-03
# std rel error:  1.05E-03

# %%
# SECOND TRY
fixed_dim, dim = 0, 10

# function definition
deriv_map = np.array([0] * dim).reshape(-1, dim)
def f_example2(y):
    """
    idx 0 -> no deriv
    """
    return 6 + 4 * torch.exp(-y) - 10 * torch.exp(- y / 2) + torch.exp( y / 2) - torch.exp( y )

def f_example(y):
    """
    idx 0 -> no deriv
    """
    return 6 + 4 * torch.exp(-y[0]) - 10 * torch.exp(- y[0] / 2) + torch.exp( y[0] / 2) - torch.exp( y[0] )

dgm_deriv_map = np.concatenate((deriv_map, 2 * np.identity(dim)), axis=0)
def dgm_f_example(y):
    """
    idx 0      -> no deriv
    idx 1 to n -> second deriv
    """
    return .5 * y[1:].sum(axis=0) + 6 + 4 * torch.exp(-y[0]) - 10 * torch.exp(- y[0] / 2) + torch.exp( y[0] / 2) - torch.exp( y[0] ) 

def phi_example(x):
    return 2* torch.log(1 + 1 / ( 1 + torch.exp(x.sum(dim=0) / math.sqrt(dim) )))

def exact_example(t, x, T):
    return 2*np.log(1 + 1/(1 + np.exp(x.sum(axis=0)/np.sqrt(dim) - (T - t))))

t_lo, t_hi, x_lo, x_hi, n = 0., 0.5, -8., 8., 0
grid = np.linspace(x_lo, x_hi, 100)
x_mid = (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

T = t_hi
true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)

# %%
# SECOND TRY
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # verbose=True, debug_mode=True, 
                    # disable_branch=True, disable_branch_NPP23=True, 
                    disable_galerkin=True, disable_bsde=True,
                    T=T, device=device, epochs=3000, fname="exp_example",
                    branch_nb_states=100000, branch_nb_path_per_state=10, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=100000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 501 seconds; L1 error: 5.87E-03; L2 error: 4.50E-05; rel error: 8.24E-03.
# total runtime: 501 seconds.
# #### Starting NPP23 deep branching method with seed 0 - 1 out of 10 times
# Time taken: 243 seconds; L1 error: 5.44E-03; L2 error: 5.39E-05; rel error: 5.87E-03.
# fdb runtime: 0 seconds; total runtime: 243 seconds.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 525 seconds; L1 error: 4.48E-03; L2 error: 4.28E-05; rel error: 5.80E-03.
# total runtime: 525 seconds.
# #### Starting NPP23 deep branching method with seed 1 - 2 out of 10 times
# Time taken: 241 seconds; L1 error: 5.78E-03; L2 error: 4.50E-05; rel error: 8.68E-03.
# fdb runtime: 0 seconds; total runtime: 241 seconds.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 499 seconds; L1 error: 7.49E-03; L2 error: 1.00E-04; rel error: 1.54E-02.
# total runtime: 499 seconds.
# #### Starting NPP23 deep branching method with seed 2 - 3 out of 10 times
# Time taken: 238 seconds; L1 error: 1.25E-02; L2 error: 3.25E-04; rel error: 1.59E-02.
# fdb runtime: 0 seconds; total runtime: 238 seconds.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 494 seconds; L1 error: 4.74E-03; L2 error: 4.24E-05; rel error: 6.37E-03.
# total runtime: 494 seconds.
# #### Starting NPP23 deep branching method with seed 3 - 4 out of 10 times
# Time taken: 263 seconds; L1 error: 4.55E-03; L2 error: 6.23E-05; rel error: 4.83E-03.
# fdb runtime: 0 seconds; total runtime: 263 seconds.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 507 seconds; L1 error: 2.55E-02; L2 error: 1.81E-03; rel error: 2.88E-02.
# total runtime: 507 seconds.
# #### Starting NPP23 deep branching method with seed 4 - 5 out of 10 times
# Time taken: 242 seconds; L1 error: 2.48E-02; L2 error: 2.37E-03; rel error: 4.80E-02.
# fdb runtime: 0 seconds; total runtime: 242 seconds.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 492 seconds; L1 error: 6.21E-03; L2 error: 5.09E-05; rel error: 7.84E-03.
# total runtime: 492 seconds.
# #### Starting NPP23 deep branching method with seed 5 - 6 out of 10 times
# Time taken: 235 seconds; L1 error: 2.98E+00; L2 error: 1.39E+02; rel error: 3.45E+00.
# fdb runtime: 0 seconds; total runtime: 235 seconds.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 485 seconds; L1 error: 6.16E-03; L2 error: 1.65E-04; rel error: 7.42E-03.
# total runtime: 485 seconds.
# #### Starting NPP23 deep branching method with seed 6 - 7 out of 10 times
# Time taken: 237 seconds; L1 error: 6.83E-03; L2 error: 8.21E-05; rel error: 7.13E-03.
# fdb runtime: 0 seconds; total runtime: 237 seconds.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 488 seconds; L1 error: 5.24E-03; L2 error: 5.12E-05; rel error: 6.28E-03.
# total runtime: 488 seconds.
# #### Starting NPP23 deep branching method with seed 7 - 8 out of 10 times
# Time taken: 242 seconds; L1 error: 4.89E-03; L2 error: 3.55E-05; rel error: 7.31E-03.
# fdb runtime: 0 seconds; total runtime: 242 seconds.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 471 seconds; L1 error: 2.58E-03; L2 error: 1.35E-05; rel error: 4.37E-03.
# total runtime: 471 seconds.
# #### Starting NPP23 deep branching method with seed 8 - 9 out of 10 times
# Time taken: 231 seconds; L1 error: 1.03E-02; L2 error: 2.28E-04; rel error: 1.14E-02.
# fdb runtime: 0 seconds; total runtime: 231 seconds.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 472 seconds; L1 error: 5.29E-03; L2 error: 5.69E-05; rel error: 5.60E-03.
# total runtime: 472 seconds.
# #### Starting NPP23 deep branching method with seed 9 - 10 out of 10 times
# Time taken: 228 seconds; L1 error: 3.51E-02; L2 error: 8.26E-03; rel error: 6.08E-02.
# fdb runtime: 0 seconds; total runtime: 228 seconds.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        493
# total runtime:  493
# mean L1 error:  7.36E-03
# std L1 error:   6.17E-03
# mean L2 error:  2.38E-04
# std L2 error:   5.27E-04
# mean rel error: 9.61E-03
# std rel error:  7.01E-03
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        240
# fdb runtime:    0
# total runtime:  240
# mean L1 error:  3.09E-01
# std L1 error:   8.90E-01
# mean L2 error:  1.39E+01
# std L2 error:   4.16E+01
# mean rel error: 3.62E-01
# std rel error:  1.03E+00

# %%
fixed_dim, dim = 0, 100

# function definition
deriv_map = np.array([0] * dim).reshape(-1, dim)
def f_example2(y):
    """
    idx 0 -> no deriv
    """
    return 6 + 4 * torch.exp(-y) - 10 * torch.exp(- y / 2) + torch.exp( y / 2) - torch.exp( y )

def f_example(y):
    """
    idx 0 -> no deriv
    """
    return 6 + 4 * torch.exp(-y[0]) - 10 * torch.exp(- y[0] / 2) + torch.exp( y[0] / 2) - torch.exp( y[0] )

dgm_deriv_map = np.concatenate((deriv_map, 2 * np.identity(dim)), axis=0)
def dgm_f_example(y):
    """
    idx 0      -> no deriv
    idx 1 to n -> second deriv
    """
    return .5 * y[1:].sum(axis=0) + 6 + 4 * torch.exp(-y[0]) - 10 * torch.exp(- y[0] / 2) + torch.exp( y[0] / 2) - torch.exp( y[0] ) 

def phi_example(x):
    return 2* torch.log(1 + 1 / ( 1 + torch.exp(x.sum(dim=0) / math.sqrt(dim) )))

def exact_example(t, x, T):
    return 2*np.log(1 + 1/(1 + np.exp(x.sum(axis=0)/np.sqrt(dim) - (T - t))))

t_lo, t_hi, x_lo, x_hi, n = 0., 0.5, -7.*math.sqrt(dim), 7.*math.sqrt(dim), 0
grid = np.linspace(x_lo, x_hi, 100)
x_mid = (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

T = t_hi
true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # verbose=True, debug_mode=True, 
                    # disable_branch=True, 
                    # disable_branch_NPP23=True, 
                    disable_galerkin=True, # disable_bsde=True,
                    T=T, device=device, epochs=3000, fname="exp_example",
                    branch_nb_states=2000, branch_nb_path_per_state=1000, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=100000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 332 seconds; L1 error: 5.19E-03; L2 error: 5.11E-05; rel error: 2.48E-02.
# total runtime: 332 seconds.
# #### Starting NPP23 deep branching method with seed 0 - 1 out of 10 times
# Time taken: 86 seconds; L1 error: 4.98E-03; L2 error: 1.18E-04; rel error: 2.10E-02.
# fdb runtime: 0 seconds; total runtime: 87 seconds.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 234 seconds; L1 error: 3.50E-03; L2 error: 1.88E-05; rel error: 7.04E-02.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 309 seconds; L1 error: 6.91E-03; L2 error: 1.59E-04; rel error: 2.09E-02.
# total runtime: 309 seconds.
# #### Starting NPP23 deep branching method with seed 1 - 2 out of 10 times
# Time taken: 87 seconds; L1 error: 5.72E-03; L2 error: 1.25E-04; rel error: 1.80E-02.
# fdb runtime: 0 seconds; total runtime: 87 seconds.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 228 seconds; L1 error: 2.29E-03; L2 error: 8.80E-06; rel error: 5.17E-02.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 321 seconds; L1 error: 4.31E-03; L2 error: 4.72E-05; rel error: 1.86E-02.
# total runtime: 321 seconds.
# #### Starting NPP23 deep branching method with seed 2 - 3 out of 10 times
# Time taken: 88 seconds; L1 error: 5.78E-03; L2 error: 7.55E-05; rel error: 1.84E-02.
# fdb runtime: 0 seconds; total runtime: 88 seconds.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 229 seconds; L1 error: 3.27E-03; L2 error: 1.92E-05; rel error: 7.95E-02.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 328 seconds; L1 error: 3.84E-03; L2 error: 3.76E-05; rel error: 1.02E-02.
# total runtime: 328 seconds.
# #### Starting NPP23 deep branching method with seed 3 - 4 out of 10 times
# Time taken: 85 seconds; L1 error: 5.45E-03; L2 error: 5.92E-05; rel error: 2.93E-02.
# fdb runtime: 0 seconds; total runtime: 85 seconds.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 231 seconds; L1 error: 2.63E-03; L2 error: 1.63E-05; rel error: 2.18E-02.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 324 seconds; L1 error: 7.03E-03; L2 error: 1.09E-04; rel error: 3.36E-02.
# total runtime: 324 seconds.
# #### Starting NPP23 deep branching method with seed 4 - 5 out of 10 times
# Time taken: 86 seconds; L1 error: 5.59E-03; L2 error: 7.17E-05; rel error: 4.71E-02.
# fdb runtime: 0 seconds; total runtime: 86 seconds.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 229 seconds; L1 error: 2.19E-03; L2 error: 1.06E-05; rel error: 4.65E-02.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 314 seconds; L1 error: 5.10E-03; L2 error: 5.62E-05; rel error: 3.14E-02.
# total runtime: 314 seconds.
# #### Starting NPP23 deep branching method with seed 5 - 6 out of 10 times
# Time taken: 86 seconds; L1 error: 4.47E-03; L2 error: 8.51E-05; rel error: 1.20E-02.
# fdb runtime: 0 seconds; total runtime: 86 seconds.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 229 seconds; L1 error: 2.84E-03; L2 error: 1.88E-05; rel error: 2.69E-02.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 327 seconds; L1 error: 5.60E-03; L2 error: 7.18E-05; rel error: 1.47E-02.
# total runtime: 327 seconds.
# #### Starting NPP23 deep branching method with seed 6 - 7 out of 10 times
# Time taken: 90 seconds; L1 error: 4.36E-03; L2 error: 5.32E-05; rel error: 1.54E-02.
# fdb runtime: 0 seconds; total runtime: 90 seconds.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 232 seconds; L1 error: 3.14E-03; L2 error: 2.09E-05; rel error: 6.18E-02.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 316 seconds; L1 error: 6.70E-03; L2 error: 1.22E-04; rel error: 3.61E-02.
# total runtime: 316 seconds.
# #### Starting NPP23 deep branching method with seed 7 - 8 out of 10 times
# Time taken: 87 seconds; L1 error: 4.61E-03; L2 error: 5.22E-05; rel error: 2.12E-02.
# fdb runtime: 0 seconds; total runtime: 87 seconds.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 234 seconds; L1 error: 2.37E-03; L2 error: 1.57E-05; rel error: 1.59E-02.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 324 seconds; L1 error: 6.46E-03; L2 error: 8.98E-05; rel error: 4.21E-02.
# total runtime: 324 seconds.
# #### Starting NPP23 deep branching method with seed 8 - 9 out of 10 times
# Time taken: 88 seconds; L1 error: 4.57E-03; L2 error: 6.16E-05; rel error: 2.87E-02.
# fdb runtime: 0 seconds; total runtime: 88 seconds.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 231 seconds; L1 error: 1.95E-03; L2 error: 9.57E-06; rel error: 1.71E-02.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 325 seconds; L1 error: 2.80E-03; L2 error: 1.57E-05; rel error: 2.66E-02.
# total runtime: 325 seconds.
# #### Starting NPP23 deep branching method with seed 9 - 10 out of 10 times
# Time taken: 91 seconds; L1 error: 5.12E-03; L2 error: 6.27E-05; rel error: 3.46E-02.
# fdb runtime: 0 seconds; total runtime: 91 seconds.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 232 seconds; L1 error: 3.07E-03; L2 error: 2.00E-05; rel error: 3.29E-02.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        322
# total runtime:  322
# mean L1 error:  5.39E-03
# std L1 error:   1.35E-03
# mean L2 error:  7.60E-05
# std L2 error:   4.17E-05
# mean rel error: 2.59E-02
# std rel error:  9.52E-03
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        88
# fdb runtime:    0
# total runtime:  88
# mean L1 error:  5.07E-03
# std L1 error:   5.19E-04
# mean L2 error:  7.65E-05
# std L2 error:   2.47E-05
# mean rel error: 2.46E-02
# std rel error:  9.97E-03
#
#
# ######## Summary for deep BSDE method
# runtime:        231
# mean L1 error:  2.72E-03
# std L1 error:   4.91E-04
# mean L2 error:  1.59E-05
# std L2 error:   4.34E-06
# mean rel error: 4.24E-02
# std rel error:  2.18E-02

# %%
fixed_dim, dim = 0, 300

# function definition
deriv_map = np.array([0] * dim).reshape(-1, dim)

dgm_deriv_map = np.concatenate((deriv_map, 2 * np.identity(dim)), axis=0)

t_lo, t_hi, x_lo, x_hi, n = 0., 0.5, -7.*math.sqrt(dim), 7.*math.sqrt(dim), 0
grid = np.linspace(x_lo, x_hi, 100)
x_mid = (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

T = t_hi
true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # verbose=True, debug_mode=True, 
                    # disable_branch=True, 
                    # disable_branch_NPP23=True, 
                    disable_galerkin=True, # disable_bsde=True,
                    T=T, device=device, epochs=3000, fname="exp_example",
                    branch_nb_states=2000, branch_nb_path_per_state=1000, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=100000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 1094 seconds; L1 error: 5.94E-03; L2 error: 7.64E-05; rel error: 1.90E-02.
# total runtime: 1094 seconds.
# #### Starting NPP23 deep branching method with seed 0 - 1 out of 10 times
# Time taken: 176 seconds; L1 error: 8.40E-03; L2 error: 3.60E-04; rel error: 2.32E-02.
# fdb runtime: 0 seconds; total runtime: 176 seconds.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 519 seconds; L1 error: 5.86E-03; L2 error: 5.97E-05; rel error: 1.80E-01.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 1042 seconds; L1 error: 5.34E-03; L2 error: 6.76E-05; rel error: 1.61E-02.
# total runtime: 1042 seconds.
# #### Starting NPP23 deep branching method with seed 1 - 2 out of 10 times
# Time taken: 175 seconds; L1 error: 7.07E-03; L2 error: 1.56E-04; rel error: 2.92E-02.
# fdb runtime: 0 seconds; total runtime: 175 seconds.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 519 seconds; L1 error: 4.21E-03; L2 error: 4.02E-05; rel error: 6.42E-02.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 1060 seconds; L1 error: 8.67E-03; L2 error: 3.09E-04; rel error: 5.49E-02.
# total runtime: 1060 seconds.
# #### Starting NPP23 deep branching method with seed 2 - 3 out of 10 times
# Time taken: 179 seconds; L1 error: 5.46E-03; L2 error: 8.12E-05; rel error: 3.94E-02.
# fdb runtime: 0 seconds; total runtime: 180 seconds.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 520 seconds; L1 error: 4.56E-03; L2 error: 3.78E-05; rel error: 9.53E-02.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 1044 seconds; L1 error: 5.88E-03; L2 error: 7.83E-05; rel error: 1.26E-02.
# total runtime: 1044 seconds.
# #### Starting NPP23 deep branching method with seed 3 - 4 out of 10 times
# Time taken: 173 seconds; L1 error: 6.24E-03; L2 error: 7.72E-05; rel error: 3.43E-02.
# fdb runtime: 0 seconds; total runtime: 173 seconds.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 519 seconds; L1 error: 3.83E-03; L2 error: 2.91E-05; rel error: 1.10E-01.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 1088 seconds; L1 error: 7.36E-03; L2 error: 1.42E-04; rel error: 2.68E-02.
# total runtime: 1088 seconds.
# #### Starting NPP23 deep branching method with seed 4 - 5 out of 10 times
# Time taken: 173 seconds; L1 error: 6.99E-03; L2 error: 1.28E-04; rel error: 2.06E-02.
# fdb runtime: 0 seconds; total runtime: 173 seconds.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 520 seconds; L1 error: 3.72E-03; L2 error: 2.58E-05; rel error: 4.67E-02.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 1072 seconds; L1 error: 7.79E-03; L2 error: 3.90E-04; rel error: 5.13E-02.
# total runtime: 1072 seconds.
# #### Starting NPP23 deep branching method with seed 5 - 6 out of 10 times
# Time taken: 179 seconds; L1 error: 6.10E-03; L2 error: 8.15E-05; rel error: 2.33E-02.
# fdb runtime: 0 seconds; total runtime: 179 seconds.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 520 seconds; L1 error: 3.55E-03; L2 error: 2.29E-05; rel error: 2.89E-02.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 1037 seconds; L1 error: 7.42E-03; L2 error: 1.47E-04; rel error: 1.79E-02.
# total runtime: 1037 seconds.
# #### Starting NPP23 deep branching method with seed 6 - 7 out of 10 times
# Time taken: 173 seconds; L1 error: 6.36E-03; L2 error: 7.87E-05; rel error: 1.20E-02.
# fdb runtime: 0 seconds; total runtime: 173 seconds.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 521 seconds; L1 error: 4.44E-03; L2 error: 3.19E-05; rel error: 1.22E-01.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 1070 seconds; L1 error: 6.05E-03; L2 error: 7.49E-05; rel error: 1.60E-02.
# total runtime: 1070 seconds.
# #### Starting NPP23 deep branching method with seed 7 - 8 out of 10 times
# Time taken: 173 seconds; L1 error: 6.45E-03; L2 error: 7.77E-05; rel error: 1.48E-02.
# fdb runtime: 0 seconds; total runtime: 173 seconds.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 519 seconds; L1 error: NAN; L2 error: NAN; rel error: NAN.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 1033 seconds; L1 error: 6.60E-03; L2 error: 8.63E-05; rel error: 1.41E-02.
# total runtime: 1033 seconds.
# #### Starting NPP23 deep branching method with seed 8 - 9 out of 10 times
# Time taken: 174 seconds; L1 error: 5.45E-03; L2 error: 7.02E-05; rel error: 2.36E-02.
# fdb runtime: 0 seconds; total runtime: 174 seconds.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 520 seconds; L1 error: 5.73E-03; L2 error: 5.14E-05; rel error: 1.31E-01.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 1019 seconds; L1 error: 7.23E-03; L2 error: 1.60E-04; rel error: 2.12E-02.
# total runtime: 1019 seconds.
# #### Starting NPP23 deep branching method with seed 9 - 10 out of 10 times
# Time taken: 173 seconds; L1 error: 6.76E-03; L2 error: 8.72E-05; rel error: 2.91E-02.
# fdb runtime: 0 seconds; total runtime: 173 seconds.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 520 seconds; L1 error: 5.62E-03; L2 error: 3.81E-05; rel error: 1.55E-01.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        1056
# total runtime:  1056
# mean L1 error:  6.83E-03
# std L1 error:   9.84E-04
# mean L2 error:  1.53E-04
# std L2 error:   1.05E-04
# mean rel error: 2.50E-02
# std rel error:  1.46E-02
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        175
# fdb runtime:    0
# total runtime:  175
# mean L1 error:  6.53E-03
# std L1 error:   8.16E-04
# mean L2 error:  1.20E-04
# std L2 error:   8.40E-05
# mean rel error: 2.50E-02
# std rel error:  7.93E-03
#
#
# ######## Summary for deep BSDE method
# runtime:        520
# mean L1 error:  NAN
# std L1 error:   NAN
# mean L2 error:  NAN
# std L2 error:   NAN
# mean rel error: NAN
# std rel error:  NAN
