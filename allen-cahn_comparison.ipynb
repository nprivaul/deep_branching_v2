# %% [raw]
# # Imports & basic configuration

# %%
try:
    # always cd to the right directory in google colab
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd "/content/drive/MyDrive/Colab Notebooks/branch_full/deep_branching"
except:
    pass

import math
from scipy import special
import numpy as np
import torch
import matplotlib.pyplot as plt
import time
from branch import Net
# from compare_performance import compare_performance
from branch_NPP23 import Net_NPP23
from galerkin import DGMNet
from bsde import BSDENet
import logging

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# perfect reproducibility is not guaranteed with different version of torch
#
import torchaudio
import torchvision

print(f"torch version: {torch.__version__}")
print(f"torchaudio version: {torchaudio.__version__}")
print(f"torchvision version: {torchvision.__version__}")
# Out:
# torch version: 2.5.1+cu124
# torchaudio version: 2.5.1+cu124
# torchvision version: 0.20.1+cu124

# %%
print("Information of the allocated GPU.")
# !nvidia-smi
# Out:
# Information of the allocated GPU.
# Fri Nov 15 16:55:42 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A4000               Off |   00000000:21:00.0  On |                  Off |
# | 41%   40C    P8             19W /  140W |    3731MiB /  16376MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2549      G   /usr/lib/xorg/Xorg                            421MiB |
# |    0   N/A  N/A      2809      G   /usr/bin/gnome-shell                          413MiB |
# |    0   N/A  N/A      3500      G   ...3/usr/bin/snapd-desktop-integration         44MiB |
# |    0   N/A  N/A      3511      G   /usr/libexec/xdg-desktop-portal-gnome        1875MiB |
# |    0   N/A  N/A      3540      G   ...AAAAAAAACAAAAAAAAAA= --shared-files         72MiB |
# |    0   N/A  N/A     17756      G   ...46ad057035c77b8e0801dd9e381f28b99ed         89MiB |
# |    0   N/A  N/A    475387      G   ...seed-version=20241104-180211.094000         95MiB |
# |    0   N/A  N/A    689523      G   ...irefox/5239/usr/lib/firefox/firefox          0MiB |
# |    0   N/A  N/A    692780      G   ...usr/lib/thunderbird/thunderbird-bin          0MiB |
# |    0   N/A  N/A   1086068      G   ...ures=SpareRendererForSitePerProcess         76MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# performance evaluation for PDE
def compare_performance(
    grid_1d,
    grid_nd,
    grid_with_t,
    t_lo,
    true,
    terminal,
    fname=None,
    debug_mode=False,
    disable_galerkin=False,
    disable_bsde=False,
    disable_branch=False,
    disable_branch_NPP23=False,
    seeds=list(range(10)),
    **kwargs,
):
    x_lo, x_hi = grid_nd.min(), grid_nd.max()
    grid_nd = grid_nd.astype(np.float32)
    grid_with_t = grid_with_t.astype(np.float32)

#    fname = f"{fname}_dim_{grid_nd.shape[0]}" if fname is not None else None
    fname = f"{fname}" if fname is not None else None
    counter = 1

    branch_runtime, branch_l1_error, branch_l2_error, branch_rel_error, branch = (
        [],
        [],
        [],
        [],
        0,
    )
    branch_NPP23_runtime, branch_NPP23_l1_error, branch_NPP23_l2_error, branch_NPP23_rel_error, branch_NPP23 = (
        [],
        [],
        [],
        [],
        0,
    )
    branch_total_runtime = []
    branch_NPP23_fdb_runtime, branch_NPP23_total_runtime = [], []
    dgm_runtime, dgm_l1_error, dgm_l2_error, dgm_rel_error, dgm = [], [], [], [], 0
    bsde_runtime, bsde_l1_error, bsde_l2_error, bsde_rel_error, bsde = [], [], [], [], 0
    for seed in seeds:
        ######### Deep branching method
        if not disable_branch:
            torch.manual_seed(seed)
            print(
                f"#### Starting deep branching method with seed {seed} - {counter} out of {len(seeds)} times"
            )
            start = time.time()
            model = Net(t_lo=t_lo, t_hi=t_hi, x_lo=x_lo, x_hi=x_hi, **kwargs)
            model.train_and_eval(debug_mode)
            branch_total_runtime.append(time.time() - start)
            branch_runtime.append(branch_total_runtime[-1])
            tmp = (
                model(torch.tensor(grid_with_t.T, device=device)).detach().cpu().numpy()
            )
            branch += tmp
            branch_l1_error.append((np.abs(tmp - true)).mean())
            branch_l2_error.append(((tmp - true) ** 2).mean())
            branch_rel_error.append((np.abs(tmp - true) / np.abs(true)).mean())
            print(
                f"Time taken: {branch_runtime[-1]:.0f} seconds; L1 error: {branch_l1_error[-1]:.2E}; L2 error: {branch_l2_error[-1]:.2E}; rel error: {branch_rel_error[-1]:.2E}."
            )
            print(
                f"total runtime: {branch_total_runtime[-1]:.0f} seconds."
            )
            
        ######### NPP23 Deep branching method
        if not disable_branch_NPP23:
            torch.manual_seed(seed)
            print(
                f"#### Starting NPP23 deep branching method with seed {seed} - {counter} out of {len(seeds)} times"
            )
            start = time.time()
            model_NPP23 = Net_NPP23(t_lo=t_lo, t_hi=t_lo, x_lo=x_lo, x_hi=x_hi, **kwargs)
            model_NPP23.train_and_eval(debug_mode)
            branch_NPP23_total_runtime.append(time.time() - start)
            branch_NPP23_fdb_runtime.append(model_NPP23.fdb_runtime)
            branch_NPP23_runtime.append(branch_NPP23_total_runtime[-1] - branch_NPP23_fdb_runtime[-1])
            tmp = (
                model_NPP23(torch.tensor(grid_with_t.T, device=device)).detach().cpu().numpy()
            )
            branch_NPP23 += tmp
            branch_NPP23_l1_error.append((np.abs(tmp - true)).mean())
            branch_NPP23_l2_error.append(((tmp - true) ** 2).mean())
            branch_NPP23_rel_error.append((np.abs(tmp - true) / np.abs(true)).mean())
            print(
                f"Time taken: {branch_NPP23_runtime[-1]:.0f} seconds; L1 error: {branch_NPP23_l1_error[-1]:.2E}; L2 error: {branch_NPP23_l2_error[-1]:.2E}; rel error: {branch_NPP23_rel_error[-1]:.2E}."
            )
            print(
                f"fdb runtime: {branch_NPP23_fdb_runtime[-1]:.0f} seconds; total runtime: {branch_NPP23_total_runtime[-1]:.0f} seconds."
            )

        ######### Deep galerkin method
        if not disable_galerkin:
            torch.manual_seed(seed)
            print(
                f"#### Starting deep galerkin method with seed {seed} - {counter} out of {len(seeds)} times"
            )
            start = time.time()
            model = DGMNet(t_lo=t_lo, t_hi=kwargs["T"], x_lo=x_lo, x_hi=x_hi, **kwargs)
            model.train_and_eval(debug_mode)
            dgm_runtime.append(time.time() - start)
            tmp = (
                model(torch.tensor(grid_with_t.T, device=device)).detach().cpu().numpy()
            )
            dgm += tmp
            dgm_l1_error.append((np.abs(tmp - true)).mean())
            dgm_l2_error.append(((tmp - true) ** 2).mean())
            dgm_rel_error.append((np.abs(tmp - true) / np.abs(true)).mean())
            print(
                f"Time taken: {dgm_runtime[-1]:.0f} seconds; L1 error: {dgm_l1_error[-1]:.2E}; L2 error: {dgm_l2_error[-1]:.2E}; rel error: {dgm_rel_error[-1]:.2E}."
            )

        ######### Deep BSDE method
        if not disable_bsde:
            torch.manual_seed(seed)
            print(
                f"#### Starting deep BSDE method with seed {seed} - {counter} out of {len(seeds)} times"
            )
            start = time.time()
            model = BSDENet(t_lo=t_lo, t_hi=kwargs["T"], x_lo=x_lo, x_hi=x_hi, **kwargs)
            model.train_and_eval(debug_mode)
            bsde_runtime.append(time.time() - start)
            tmp = (
                model(torch.tensor(grid_nd.T, device=device))
                .squeeze(-1)
                .detach()
                .cpu()
                .numpy()
            )
            bsde += tmp
            bsde_l1_error.append((np.abs(tmp - true)).mean())
            bsde_l2_error.append(((tmp - true) ** 2).mean())
            bsde_rel_error.append((np.abs(tmp - true) / np.abs(true)).mean())
            print(
                f"Time taken: {bsde_runtime[-1]:.0f} seconds; L1 error: {bsde_l1_error[-1]:.2E}; L2 error: {bsde_l2_error[-1]:.2E}; rel error: {bsde_rel_error[-1]:.2E}."
            )

        print("\n")
        counter += 1

    # Plot
    f = plt.figure()
    plt.plot(grid_1d, true, label="True solution")
    plt.plot(grid_1d, terminal, label="Terminal condition")
    # save into csv
    if fname is not None:
        plt_data = np.stack((grid_1d, true, terminal), axis=-1)
        plt_header = "x, true, terminal"

    if not disable_branch:
        branch /= len(seeds)
        branch_runtime, branch_l1_error, branch_l2_error, branch_rel_error = (
            np.array(branch_runtime),
            np.array(branch_l1_error),
            np.array(branch_l2_error),
            np.array(branch_rel_error),
        )
        branch_total_runtime = np.array(branch_total_runtime)
        print("\n")
        print("######## Summary for deep branching method")
        print(f"runtime:        {branch_runtime.mean():.0f}")
        print(f"total runtime:  {branch_total_runtime.mean():.0f}")
        print(f"mean L1 error:  {branch_l1_error.mean():.2E}")
        print(f"std L1 error:   {branch_l1_error.std():.2E}")
        print(f"mean L2 error:  {branch_l2_error.mean():.2E}")
        print(f"std L2 error:   {branch_l2_error.std():.2E}")
        print(f"mean rel error: {branch_rel_error.mean():.2E}")
        print(f"std rel error:  {branch_rel_error.std():.2E}")
        # Plot
        plt.plot(grid_1d, branch, label="Deep branching")
        # save into csv
        if fname is not None:
            plt_data = np.concatenate(
                (plt_data, np.expand_dims(branch, axis=-1)), axis=-1
            )
            plt_header += ", branch"
            data = np.stack(
                (branch_runtime, branch_l1_error, branch_l2_error, branch_rel_error),
                axis=-1,
            )
            np.savetxt(
                "log/branch_" + fname + ".csv",
                data,
                delimiter=",",
                header="runtime,l1_error,l2_error,rel_error",
                comments="",
            )
            
    if not disable_branch_NPP23:
        branch_NPP23 /= len(seeds)
        branch_NPP23_runtime, branch_NPP23_l1_error, branch_NPP23_l2_error, branch_NPP23_rel_error = (
            np.array(branch_NPP23_runtime),
            np.array(branch_NPP23_l1_error),
            np.array(branch_NPP23_l2_error),
            np.array(branch_NPP23_rel_error),
        )
        branch_NPP23_fdb_runtime, branch_NPP23_total_runtime = np.array(
            branch_NPP23_fdb_runtime
        ), np.array(branch_NPP23_total_runtime)
        print("\n")
        print("######## Summary for NPP23 deep branching method")
        print(f"runtime:        {branch_NPP23_runtime.mean():.0f}")
        print(f"fdb runtime:    {branch_NPP23_fdb_runtime.mean():.0f}")
        print(f"total runtime:  {branch_NPP23_total_runtime.mean():.0f}")
        print(f"mean L1 error:  {branch_NPP23_l1_error.mean():.2E}")
        print(f"std L1 error:   {branch_NPP23_l1_error.std():.2E}")
        print(f"mean L2 error:  {branch_NPP23_l2_error.mean():.2E}")
        print(f"std L2 error:   {branch_NPP23_l2_error.std():.2E}")
        print(f"mean rel error: {branch_NPP23_rel_error.mean():.2E}")
        print(f"std rel error:  {branch_NPP23_rel_error.std():.2E}")
        # Plot
        plt.plot(grid_1d, branch_NPP23, label="NPP23 Deep branching")
        # save into csv
        if fname is not None:
            plt_data = np.concatenate(
                (plt_data, np.expand_dims(branch_NPP23, axis=-1)), axis=-1
            )
            plt_header += ", branch"
            data = np.stack(
                (branch_NPP23_runtime, branch_NPP23_l1_error, branch_NPP23_l2_error, branch_NPP23_rel_error),
                axis=-1,
            )
            np.savetxt(
                "log/branch_" + fname + ".csv",
                data,
                delimiter=",",
                header="runtime,l1_error,l2_error,rel_error",
                comments="",
            )

    if not disable_galerkin:
        dgm /= len(seeds)
        dgm_runtime, dgm_l1_error, dgm_l2_error, dgm_rel_error = (
            np.array(dgm_runtime),
            np.array(dgm_l1_error),
            np.array(dgm_l2_error),
            np.array(dgm_rel_error),
        )
        print("\n")
        print("######## Summary for deep galerkin method")
        print(f"runtime:        {dgm_runtime.mean():.0f}")
        print(f"mean L1 error:  {dgm_l1_error.mean():.2E}")
        print(f"std L1 error:   {dgm_l1_error.std():.2E}")
        print(f"mean L2 error:  {dgm_l2_error.mean():.2E}")
        print(f"std L2 error:   {dgm_l2_error.std():.2E}")
        print(f"mean rel error: {dgm_rel_error.mean():.2E}")
        print(f"std rel error:  {dgm_rel_error.std():.2E}")
        # Plot
        plt.plot(grid_1d, dgm, label="Deep Galerkin")
        # save into csv
        if fname is not None:
            plt_data = np.concatenate((plt_data, np.expand_dims(dgm, axis=-1)), axis=-1)
            plt_header += ", dgm"
            data = np.stack(
                (dgm_runtime, dgm_l1_error, dgm_l2_error, dgm_rel_error), axis=-1
            )
            np.savetxt(
                "log/dgm_" + fname + ".csv",
                data,
                delimiter=",",
                header="runtime,l1_error,l2_error,rel_error",
                comments="",
            )

    ######### Deep BSDE method
    if not disable_bsde:
        bsde /= len(seeds)
        bsde_runtime, bsde_l1_error, bsde_l2_error, bsde_rel_error = (
            np.array(bsde_runtime),
            np.array(bsde_l1_error),
            np.array(bsde_l2_error),
            np.array(bsde_rel_error),
        )
        print("\n")
        print("######## Summary for deep BSDE method")
        print(f"runtime:        {bsde_runtime.mean():.0f}")
        print(f"mean L1 error:  {bsde_l1_error.mean():.2E}")
        print(f"std L1 error:   {bsde_l1_error.std():.2E}")
        print(f"mean L2 error:  {bsde_l2_error.mean():.2E}")
        print(f"std L2 error:   {bsde_l2_error.std():.2E}")
        print(f"mean rel error: {bsde_rel_error.mean():.2E}")
        print(f"std rel error:  {bsde_rel_error.std():.2E}")
        # Plot
        plt.plot(grid_1d, bsde, label="Deep BSDE")
        # save into csv
        if fname is not None:
            plt_data = np.concatenate(
                (plt_data, np.expand_dims(bsde, axis=-1)), axis=-1
            )
            plt_header += ", bsde"
            data = np.stack(
                (bsde_runtime, bsde_l1_error, bsde_l2_error, bsde_rel_error), axis=-1
            )
            np.savetxt(
                "log/bsde_" + fname + ".csv",
                data,
                delimiter=",",
                header="runtime,l1_error,l2_error,rel_error",
                comments="",
            )

    plt.legend()
    plt.show()
    fname = f"{fname}_dim_{dim}" if fname is not None else f"demo_dim_{dim}"
    plt.savefig(f"plot/{'comparison' if fname is None else fname}.pdf")
    if fname is not None:
        np.savetxt(
            "log/plt_" + fname + ".csv", plt_data, delimiter=",", header=plt_header, comments=""
        )

# %% [markdown]
# ## Allen-Cahn

# %%
fixed_dim, dim = 0, 1

# function definition
deriv_map = np.array([0] * dim).reshape(-1, dim)
def f_example2(y):
    """
    idx 0 -> no deriv
    """
    return y - y ** 3

def f_example(y):
    """
    idx 0 -> no deriv
    """
    return y[0] - y[0] ** 3

dgm_deriv_map = np.concatenate((deriv_map, 2 * np.identity(dim)), axis=0)
def dgm_f_example(y):
    """
    idx 0      -> no deriv
    idx 1 to n -> second deriv
    """
    return .5 * y[1:].sum(axis=0) + y[0] - y[0] ** 3

def phi_example(x):
    return -0.5 - 0.5 * torch.nn.Tanh()(-.5 * x.sum(dim=0) / math.sqrt(dim))

def exact_example(t, x, T):
    return -0.5 - 0.5 * np.tanh(-.5*x.sum(axis=0)/math.sqrt(dim) + 3*(T-t)/4)

t_lo, t_hi, x_lo, x_hi, n = 0., 0., -5.*math.sqrt(dim), 5.*math.sqrt(dim), 0
grid = np.linspace(x_lo, x_hi, 100)
x_mid = (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

T = .5
true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # verbose=True, debug_mode=True, 
                    # disable_branch=True, 
                    # disable_branch_NPP23=True, 
                    # disable_galerkin=True, disable_bsde=True,
                    T=T, device=device, epochs=3000, fname="exp_example",
                    branch_nb_states=10000, branch_nb_path_per_state=1000, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=100000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 98 seconds; L1 error: 2.47E-03; L2 error: 1.48E-05; rel error: 8.58E-03.
# total runtime: 98 seconds.
# #### Starting NPP23 deep branching method with seed 0 - 1 out of 10 times
# Time taken: 82 seconds; L1 error: 1.92E-03; L2 error: 6.88E-06; rel error: 5.70E-03.
# fdb runtime: 0 seconds; total runtime: 82 seconds.
# #### Starting deep galerkin method with seed 0 - 1 out of 10 times
# Time taken: 51 seconds; L1 error: 2.84E-03; L2 error: 1.12E-05; rel error: 2.99E-02.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 115 seconds; L1 error: 5.37E-03; L2 error: 5.36E-05; rel error: 5.53E-02.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 95 seconds; L1 error: 5.20E-03; L2 error: 7.68E-05; rel error: 1.11E-02.
# total runtime: 95 seconds.
# #### Starting NPP23 beep branching method with seed 1 - 2 out of 10 times
# Time taken: 78 seconds; L1 error: 1.97E-03; L2 error: 9.70E-06; rel error: 4.55E-03.
# fdb runtime: 0 seconds; total runtime: 78 seconds.
# #### Starting deep galerkin method with seed 1 - 2 out of 10 times
# Time taken: 66 seconds; L1 error: 3.85E-04; L2 error: 3.42E-07; rel error: 5.51E-03.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 115 seconds; L1 error: 3.71E-03; L2 error: 2.54E-05; rel error: 2.31E-02.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 100 seconds; L1 error: 4.83E-03; L2 error: 5.05E-05; rel error: 8.28E-03.
# total runtime: 100 seconds.
# #### Starting NPP23 beep branching method with seed 2 - 3 out of 10 times
# Time taken: 81 seconds; L1 error: 2.96E-03; L2 error: 1.57E-05; rel error: 1.16E-02.
# fdb runtime: 0 seconds; total runtime: 81 seconds.
# #### Starting deep galerkin method with seed 2 - 3 out of 10 times
# Time taken: 65 seconds; L1 error: 2.96E-03; L2 error: 9.73E-06; rel error: 2.56E-02.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 115 seconds; L1 error: 3.45E-03; L2 error: 1.96E-05; rel error: 1.78E-02.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 94 seconds; L1 error: 2.44E-03; L2 error: 1.51E-05; rel error: 6.52E-03.
# total runtime: 94 seconds.
# #### Starting NPP23 beep branching method with seed 3 - 4 out of 10 times
# Time taken: 80 seconds; L1 error: 3.13E-03; L2 error: 2.11E-05; rel error: 5.94E-03.
# fdb runtime: 0 seconds; total runtime: 80 seconds.
# #### Starting deep galerkin method with seed 3 - 4 out of 10 times
# Time taken: 61 seconds; L1 error: 5.61E-04; L2 error: 5.41E-07; rel error: 7.38E-03.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 115 seconds; L1 error: 3.55E-03; L2 error: 2.04E-05; rel error: 3.18E-02.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 96 seconds; L1 error: 3.55E-03; L2 error: 3.20E-05; rel error: 7.27E-03.
# total runtime: 96 seconds.
# #### Starting NPP23 beep branching method with seed 4 - 5 out of 10 times
# Time taken: 92 seconds; L1 error: 2.97E-03; L2 error: 2.60E-05; rel error: 7.31E-03.
# fdb runtime: 0 seconds; total runtime: 92 seconds.
# #### Starting deep galerkin method with seed 4 - 5 out of 10 times
# Time taken: 67 seconds; L1 error: 6.22E-04; L2 error: 1.33E-06; rel error: 1.26E-02.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 116 seconds; L1 error: 3.25E-03; L2 error: 1.82E-05; rel error: 1.54E-02.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 92 seconds; L1 error: 3.54E-03; L2 error: 5.51E-05; rel error: 8.45E-03.
# total runtime: 92 seconds.
# #### Starting NPP23 beep branching method with seed 5 - 6 out of 10 times
# Time taken: 81 seconds; L1 error: 2.27E-03; L2 error: 1.26E-05; rel error: 5.07E-03.
# fdb runtime: 0 seconds; total runtime: 81 seconds.
# #### Starting deep galerkin method with seed 5 - 6 out of 10 times
# Time taken: 72 seconds; L1 error: 6.42E-04; L2 error: 6.86E-07; rel error: 9.06E-03.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 115 seconds; L1 error: 3.47E-03; L2 error: 2.21E-05; rel error: 2.35E-02.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 97 seconds; L1 error: 2.31E-03; L2 error: 9.86E-06; rel error: 4.64E-03.
# total runtime: 97 seconds.
# #### Starting NPP23 beep branching method with seed 6 - 7 out of 10 times
# Time taken: 74 seconds; L1 error: 1.62E-03; L2 error: 5.57E-06; rel error: 6.44E-03.
# fdb runtime: 0 seconds; total runtime: 74 seconds.
# #### Starting deep galerkin method with seed 6 - 7 out of 10 times
# Time taken: 67 seconds; L1 error: 3.17E-04; L2 error: 1.83E-07; rel error: 4.26E-03.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 116 seconds; L1 error: 3.50E-03; L2 error: 1.94E-05; rel error: 1.85E-02.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 96 seconds; L1 error: 4.10E-03; L2 error: 4.34E-05; rel error: 8.88E-03.
# total runtime: 96 seconds.
# #### Starting NPP23 beep branching method with seed 7 - 8 out of 10 times
# Time taken: 85 seconds; L1 error: 2.30E-03; L2 error: 1.20E-05; rel error: 1.01E-02.
# fdb runtime: 0 seconds; total runtime: 85 seconds.
# #### Starting deep galerkin method with seed 7 - 8 out of 10 times
# Time taken: 63 seconds; L1 error: 8.91E-04; L2 error: 1.01E-06; rel error: 6.08E-03.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 116 seconds; L1 error: 3.87E-03; L2 error: 3.21E-05; rel error: 3.64E-02.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 90 seconds; L1 error: 3.36E-03; L2 error: 2.89E-05; rel error: 1.13E-02.
# total runtime: 90 seconds.
# #### Starting NPP23 beep branching method with seed 8 - 9 out of 10 times
# Time taken: 82 seconds; L1 error: 2.80E-03; L2 error: 1.72E-05; rel error: 9.54E-03.
# fdb runtime: 0 seconds; total runtime: 82 seconds.
# #### Starting deep galerkin method with seed 8 - 9 out of 10 times
# Time taken: 71 seconds; L1 error: 5.89E-04; L2 error: 7.41E-07; rel error: 7.41E-03.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 116 seconds; L1 error: 3.53E-03; L2 error: 2.34E-05; rel error: 1.76E-02.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 94 seconds; L1 error: 3.10E-03; L2 error: 1.91E-05; rel error: 6.89E-03.
# total runtime: 94 seconds.
# #### Starting NPP23 beep branching method with seed 9 - 10 out of 10 times
# Time taken: 74 seconds; L1 error: 3.21E-03; L2 error: 2.71E-05; rel error: 8.02E-03.
# fdb runtime: 0 seconds; total runtime: 74 seconds.
# #### Starting deep galerkin method with seed 9 - 10 out of 10 times
# Time taken: 73 seconds; L1 error: 6.87E-04; L2 error: 1.13E-06; rel error: 1.23E-02.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 116 seconds; L1 error: 3.43E-03; L2 error: 2.04E-05; rel error: 1.83E-02.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        95
# total runtime:  95
# mean L1 error:  3.49E-03
# std L1 error:   9.38E-04
# mean L2 error:  3.46E-05
# std L2 error:   2.05E-05
# mean rel error: 8.19E-03
# std rel error:  1.92E-03
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        81
# fdb runtime:    0
# total runtime:  81
# mean L1 error:  2.52E-03
# std L1 error:   5.39E-04
# mean L2 error:  1.54E-05
# std L2 error:   7.11E-06
# mean rel error: 7.43E-03
# std rel error:  2.22E-03
#
#
# ######## Summary for deep galerkin method
# runtime:        65
# mean L1 error:  1.05E-03
# std L1 error:   9.37E-04
# mean L2 error:  2.69E-06
# std L2 error:   3.92E-06
# mean rel error: 1.20E-02
# std rel error:  8.35E-03
#
#
# ######## Summary for deep BSDE method
# runtime:        116
# mean L1 error:  3.71E-03
# std L1 error:   5.75E-04
# mean L2 error:  2.55E-05
# std L2 error:   1.01E-05
# mean rel error: 2.58E-02
# std rel error:  1.17E-02

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # verbose=True, debug_mode=True, 
                    # disable_branch=True, disable_branch_NPP23=True, disable_galerkin=True, disable_bsde=True,
                    T=T, device=device, epochs=3000, fname="allen_cahn",
                    branch_nb_states=10000, branch_nb_path_per_state=10, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=100000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 41 seconds; L1 error: 7.67E-03; L2 error: 9.28E-05; rel error: 3.77E-02.
# total runtime: 41 seconds.
# #### Starting NPP23 beep branching method with seed 0 - 1 out of 10 times
# Time taken: 36 seconds; L1 error: 3.46E-03; L2 error: 3.32E-05; rel error: 9.66E-03.
# fdb runtime: 0 seconds; total runtime: 36 seconds.
# #### Starting deep galerkin method with seed 0 - 1 out of 10 times
# Time taken: 70 seconds; L1 error: 2.84E-03; L2 error: 1.12E-05; rel error: 2.99E-02.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 114 seconds; L1 error: 5.37E-03; L2 error: 5.36E-05; rel error: 5.53E-02.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 40 seconds; L1 error: 1.03E-02; L2 error: 1.77E-04; rel error: 3.04E-02.
# total runtime: 40 seconds.
# #### Starting NPP23 beep branching method with seed 1 - 2 out of 10 times
# Time taken: 36 seconds; L1 error: 1.61E-02; L2 error: 3.80E-04; rel error: 1.19E-01.
# fdb runtime: 0 seconds; total runtime: 36 seconds.
# #### Starting deep galerkin method with seed 1 - 2 out of 10 times
# Time taken: 62 seconds; L1 error: 3.85E-04; L2 error: 3.42E-07; rel error: 5.51E-03.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 117 seconds; L1 error: 3.71E-03; L2 error: 2.54E-05; rel error: 2.31E-02.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 43 seconds; L1 error: 7.83E-03; L2 error: 8.99E-05; rel error: 3.29E-02.
# total runtime: 43 seconds.
# #### Starting NPP23 beep branching method with seed 2 - 3 out of 10 times
# Time taken: 35 seconds; L1 error: 5.29E-02; L2 error: 3.90E-03; rel error: 4.00E-01.
# fdb runtime: 0 seconds; total runtime: 35 seconds.
# #### Starting deep galerkin method with seed 2 - 3 out of 10 times
# Time taken: 63 seconds; L1 error: 2.96E-03; L2 error: 9.73E-06; rel error: 2.56E-02.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 115 seconds; L1 error: 3.45E-03; L2 error: 1.96E-05; rel error: 1.78E-02.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 36 seconds; L1 error: 1.09E-02; L2 error: 2.55E-04; rel error: 3.29E-02.
# total runtime: 36 seconds.
# #### Starting NPP23 beep branching method with seed 3 - 4 out of 10 times
# Time taken: 38 seconds; L1 error: 8.81E-03; L2 error: 2.20E-04; rel error: 2.69E-02.
# fdb runtime: 0 seconds; total runtime: 38 seconds.
# #### Starting deep galerkin method with seed 3 - 4 out of 10 times
# Time taken: 66 seconds; L1 error: 5.61E-04; L2 error: 5.41E-07; rel error: 7.38E-03.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 117 seconds; L1 error: 3.55E-03; L2 error: 2.04E-05; rel error: 3.18E-02.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 40 seconds; L1 error: 9.21E-03; L2 error: 1.36E-04; rel error: 3.51E-02.
# total runtime: 40 seconds.
# #### Starting NPP23 beep branching method with seed 4 - 5 out of 10 times
# Time taken: 35 seconds; L1 error: 3.36E-02; L2 error: 7.01E-03; rel error: 9.77E-02.
# fdb runtime: 0 seconds; total runtime: 35 seconds.
# #### Starting deep galerkin method with seed 4 - 5 out of 10 times
# Time taken: 61 seconds; L1 error: 6.22E-04; L2 error: 1.33E-06; rel error: 1.26E-02.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 119 seconds; L1 error: 3.25E-03; L2 error: 1.82E-05; rel error: 1.54E-02.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 43 seconds; L1 error: 6.95E-03; L2 error: 1.02E-04; rel error: 3.63E-02.
# total runtime: 43 seconds.
# #### Starting NPP23 beep branching method with seed 5 - 6 out of 10 times
# Time taken: 35 seconds; L1 error: 2.07E-01; L2 error: 7.77E-01; rel error: 2.91E-01.
# fdb runtime: 0 seconds; total runtime: 35 seconds.
# #### Starting deep galerkin method with seed 5 - 6 out of 10 times
# Time taken: 59 seconds; L1 error: 6.42E-04; L2 error: 6.86E-07; rel error: 9.06E-03.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 116 seconds; L1 error: 3.47E-03; L2 error: 2.21E-05; rel error: 2.35E-02.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 34 seconds; L1 error: 9.97E-03; L2 error: 1.72E-04; rel error: 2.89E-02.
# total runtime: 34 seconds.
# #### Starting NPP23 beep branching method with seed 6 - 7 out of 10 times
# Time taken: 35 seconds; L1 error: 1.27E-02; L2 error: 3.41E-04; rel error: 3.79E-02.
# fdb runtime: 0 seconds; total runtime: 35 seconds.
# #### Starting deep galerkin method with seed 6 - 7 out of 10 times
# Time taken: 63 seconds; L1 error: 3.17E-04; L2 error: 1.83E-07; rel error: 4.26E-03.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 116 seconds; L1 error: 3.50E-03; L2 error: 1.94E-05; rel error: 1.85E-02.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 33 seconds; L1 error: 1.20E-02; L2 error: 2.12E-04; rel error: 3.81E-02.
# total runtime: 33 seconds.
# #### Starting NPP23 beep branching method with seed 7 - 8 out of 10 times
# Time taken: 42 seconds; L1 error: 7.63E-03; L2 error: 1.59E-04; rel error: 1.99E-02.
# fdb runtime: 0 seconds; total runtime: 42 seconds.
# #### Starting deep galerkin method with seed 7 - 8 out of 10 times
# Time taken: 61 seconds; L1 error: 8.91E-04; L2 error: 1.01E-06; rel error: 6.08E-03.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 114 seconds; L1 error: 3.87E-03; L2 error: 3.21E-05; rel error: 3.64E-02.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 36 seconds; L1 error: 1.05E-02; L2 error: 2.20E-04; rel error: 2.84E-02.
# total runtime: 36 seconds.
# #### Starting NPP23 beep branching method with seed 8 - 9 out of 10 times
# Time taken: 34 seconds; L1 error: 2.26E-02; L2 error: 6.31E-03; rel error: 8.96E-02.
# fdb runtime: 0 seconds; total runtime: 34 seconds.
# #### Starting deep galerkin method with seed 8 - 9 out of 10 times
# Time taken: 60 seconds; L1 error: 5.89E-04; L2 error: 7.41E-07; rel error: 7.41E-03.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 116 seconds; L1 error: 3.53E-03; L2 error: 2.34E-05; rel error: 1.76E-02.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 39 seconds; L1 error: 1.09E-02; L2 error: 2.01E-04; rel error: 3.61E-02.
# total runtime: 39 seconds.
# #### Starting NPP23 beep branching method with seed 9 - 10 out of 10 times
# Time taken: 37 seconds; L1 error: 7.74E-03; L2 error: 1.26E-04; rel error: 2.20E-02.
# fdb runtime: 0 seconds; total runtime: 37 seconds.
# #### Starting deep galerkin method with seed 9 - 10 out of 10 times
# Time taken: 73 seconds; L1 error: 6.87E-04; L2 error: 1.13E-06; rel error: 1.23E-02.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 114 seconds; L1 error: 3.43E-03; L2 error: 2.04E-05; rel error: 1.83E-02.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        38
# total runtime:  38
# mean L1 error:  9.62E-03
# std L1 error:   1.56E-03
# mean L2 error:  1.66E-04
# std L2 error:   5.53E-05
# mean rel error: 3.37E-02
# std rel error:  3.37E-03
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        36
# fdb runtime:    0
# total runtime:  36
# mean L1 error:  3.73E-02
# std L1 error:   5.84E-02
# mean L2 error:  7.95E-02
# std L2 error:   2.32E-01
# mean rel error: 1.11E-01
# std rel error:  1.25E-01
#
#
# ######## Summary for deep galerkin method
# runtime:        64
# mean L1 error:  1.05E-03
# std L1 error:   9.37E-04
# mean L2 error:  2.69E-06
# std L2 error:   3.92E-06
# mean rel error: 1.20E-02
# std rel error:  8.35E-03
#
#
# ######## Summary for deep BSDE method
# runtime:        116
# mean L1 error:  3.71E-03
# std L1 error:   5.75E-04
# mean L2 error:  2.55E-05
# std L2 error:   1.01E-05
# mean rel error: 2.58E-02
# std rel error:  1.17E-02

# %%
fixed_dim, dim = 0, 300

# function definition
deriv_map = np.array([0] * dim).reshape(-1, dim)

dgm_deriv_map = np.concatenate((deriv_map, 2 * np.identity(dim)), axis=0)

t_lo, t_hi, x_lo, x_hi, n = 0., 0., -7.*math.sqrt(dim), 7.*math.sqrt(dim), 0
grid = np.linspace(x_lo, x_hi, 100)
x_mid = (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

T = .5
true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # verbose=True, debug_mode=True, 
                    # disable_branch=True, 
                    # disable_branch_NPP23=True, 
                    disable_galerkin=True, # disable_bsde=True,
                    T=T, device=device, epochs=3000, fname="exp_example",
                    branch_nb_states=1000, branch_nb_path_per_state=1000, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=100000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 563 seconds; L1 error: 9.29E-03; L2 error: 1.71E-04; rel error: 4.44E-02.
# total runtime: 563 seconds.
# #### Starting NPP23 beep branching method with seed 0 - 1 out of 10 times
# Time taken: 89 seconds; L1 error: 9.59E-03; L2 error: 1.78E-04; rel error: 4.76E-02.
# fdb runtime: 0 seconds; total runtime: 89 seconds.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 505 seconds; L1 error: 4.81E-03; L2 error: 4.07E-05; rel error: 1.38E-01.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 542 seconds; L1 error: 9.63E-03; L2 error: 1.79E-04; rel error: 4.05E-02.
# total runtime: 542 seconds.
# #### Starting NPP23 beep branching method with seed 1 - 2 out of 10 times
# Time taken: 94 seconds; L1 error: 9.00E-03; L2 error: 1.51E-04; rel error: 6.21E-02.
# fdb runtime: 0 seconds; total runtime: 94 seconds.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 505 seconds; L1 error: 5.42E-03; L2 error: 4.81E-05; rel error: 1.78E-01.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 569 seconds; L1 error: 9.45E-03; L2 error: 1.76E-04; rel error: 4.74E-02.
# total runtime: 569 seconds.
# #### Starting NPP23 beep branching method with seed 2 - 3 out of 10 times
# Time taken: 90 seconds; L1 error: 9.37E-03; L2 error: 2.01E-04; rel error: 4.00E-02.
# fdb runtime: 0 seconds; total runtime: 90 seconds.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 494 seconds; L1 error: 4.17E-03; L2 error: 3.55E-05; rel error: 1.20E-01.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 536 seconds; L1 error: 8.93E-03; L2 error: 1.64E-04; rel error: 2.95E-02.
# total runtime: 536 seconds.
# #### Starting NPP23 beep branching method with seed 3 - 4 out of 10 times
# Time taken: 96 seconds; L1 error: 1.03E-02; L2 error: 2.02E-04; rel error: 4.89E-02.
# fdb runtime: 0 seconds; total runtime: 96 seconds.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 491 seconds; L1 error: 4.07E-03; L2 error: 2.55E-05; rel error: 9.13E-02.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 538 seconds; L1 error: 9.02E-03; L2 error: 1.73E-04; rel error: 3.74E-02.
# total runtime: 538 seconds.
# #### Starting NPP23 beep branching method with seed 4 - 5 out of 10 times
# Time taken: 91 seconds; L1 error: 1.04E-02; L2 error: 2.12E-04; rel error: 6.12E-02.
# fdb runtime: 0 seconds; total runtime: 91 seconds.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 491 seconds; L1 error: 4.34E-03; L2 error: 3.72E-05; rel error: 8.82E-02.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 551 seconds; L1 error: 1.14E-02; L2 error: 3.11E-04; rel error: 3.76E-02.
# total runtime: 551 seconds.
# #### Starting NPP23 beep branching method with seed 5 - 6 out of 10 times
# Time taken: 95 seconds; L1 error: 9.32E-03; L2 error: 1.77E-04; rel error: 5.52E-02.
# fdb runtime: 0 seconds; total runtime: 95 seconds.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 496 seconds; L1 error: 4.21E-03; L2 error: 3.10E-05; rel error: 1.32E-01.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 531 seconds; L1 error: 9.49E-03; L2 error: 1.94E-04; rel error: 3.14E-02.
# total runtime: 531 seconds.
# #### Starting NPP23 beep branching method with seed 6 - 7 out of 10 times
# Time taken: 98 seconds; L1 error: 9.31E-03; L2 error: 1.70E-04; rel error: 4.23E-02.
# fdb runtime: 0 seconds; total runtime: 98 seconds.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 498 seconds; L1 error: 2.90E-03; L2 error: 1.16E-05; rel error: 1.09E-01.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 565 seconds; L1 error: 9.14E-03; L2 error: 1.59E-04; rel error: 4.09E-02.
# total runtime: 565 seconds.
# #### Starting NPP23 beep branching method with seed 7 - 8 out of 10 times
# Time taken: 102 seconds; L1 error: 9.56E-03; L2 error: 1.60E-04; rel error: 4.83E-02.
# fdb runtime: 0 seconds; total runtime: 102 seconds.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 519 seconds; L1 error: 4.65E-03; L2 error: 4.94E-05; rel error: 2.41E-01.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 586 seconds; L1 error: 9.61E-03; L2 error: 1.86E-04; rel error: 2.94E-02.
# total runtime: 586 seconds.
# #### Starting NPP23 beep branching method with seed 8 - 9 out of 10 times
# Time taken: 106 seconds; L1 error: 9.07E-03; L2 error: 1.72E-04; rel error: 3.66E-02.
# fdb runtime: 0 seconds; total runtime: 106 seconds.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 543 seconds; L1 error: 4.83E-03; L2 error: 4.64E-05; rel error: 1.12E-01.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 559 seconds; L1 error: 1.30E-02; L2 error: 4.05E-04; rel error: 5.93E-02.
# total runtime: 559 seconds.
# #### Starting NPP23 beep branching method with seed 9 - 10 out of 10 times
# Time taken: 99 seconds; L1 error: 1.03E-02; L2 error: 1.88E-04; rel error: 4.21E-02.
# fdb runtime: 0 seconds; total runtime: 99 seconds.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 497 seconds; L1 error: 5.42E-03; L2 error: 4.34E-05; rel error: 1.38E-01.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        554
# total runtime:  554
# mean L1 error:  9.89E-03
# std L1 error:   1.22E-03
# mean L2 error:  2.12E-04
# std L2 error:   7.67E-05
# mean rel error: 3.98E-02
# std rel error:  8.70E-03
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        96
# fdb runtime:    0
# total runtime:  96
# mean L1 error:  9.61E-03
# std L1 error:   4.79E-04
# mean L2 error:  1.81E-04
# std L2 error:   1.85E-05
# mean rel error: 4.84E-02
# std rel error:  8.28E-03
#
#
# ######## Summary for deep BSDE method
# runtime:        504
# mean L1 error:  4.48E-03
# std L1 error:   7.00E-04
# mean L2 error:  3.69E-05
# std L2 error:   1.11E-05
# mean rel error: 1.35E-01
# std rel error:  4.31E-02

# %%
fixed_dim, dim = 0, 500

# function definition
deriv_map = np.array([0] * dim).reshape(-1, dim)

dgm_deriv_map = np.concatenate((deriv_map, 2 * np.identity(dim)), axis=0)

t_lo, t_hi, x_lo, x_hi, n = 0., 0., -5.*math.sqrt(dim), 5.*math.sqrt(dim), 0
grid = np.linspace(x_lo, x_hi, 100)
x_mid = (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

T = .5
true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)

# %%
# Performance comparison
compare_performance(grid, grid_d_dim, grid_d_dim_with_t, t_lo, true, terminal=terminal, # seeds=[0],
                    # verbose=True, debug_mode=True, 
                    # disable_branch=True, disable_branch_NPP23=True, 
                    disable_galerkin=True, # disable_bsde=True,
                    T=T, device=device, epochs=3000, fname="allen_cahn",
                    branch_nb_states=1000, branch_nb_path_per_state=1000, branch_nb_states_per_batch=1,
                    branch_patches=1, branch_exponential_lambda=-math.log(.95)/T,                    
                    bsde_nb_states=100000, bsde_nb_time_intervals=4, outlier_percentile=1,
                    dgm_nb_states=10000, f_fun=f_example, f_fun2=f_example2, dgm_f_fun=dgm_f_example,
                    deriv_map=deriv_map, dgm_deriv_map=dgm_deriv_map, phi_fun=phi_example)
# Out:
# #### Starting deep branching method with seed 0 - 1 out of 10 times
# Time taken: 1126 seconds; L1 error: 1.28E-02; L2 error: 2.38E-04; rel error: 3.83E-02.
# total runtime: 1126 seconds.
# #### Starting NPP23 beep branching method with seed 0 - 1 out of 10 times
# Time taken: 141 seconds; L1 error: 1.32E-02; L2 error: 2.51E-04; rel error: 3.83E-02.
# fdb runtime: 0 seconds; total runtime: 142 seconds.
# #### Starting deep BSDE method with seed 0 - 1 out of 10 times
# Time taken: 725 seconds; L1 error: 6.68E-03; L2 error: 6.34E-05; rel error: 4.23E-02.
#
#
# #### Starting deep branching method with seed 1 - 2 out of 10 times
# Time taken: 1062 seconds; L1 error: 1.37E-02; L2 error: 2.65E-04; rel error: 4.30E-02.
# total runtime: 1062 seconds.
# #### Starting NPP23 beep branching method with seed 1 - 2 out of 10 times
# Time taken: 137 seconds; L1 error: 1.31E-02; L2 error: 2.41E-04; rel error: 4.35E-02.
# fdb runtime: 0 seconds; total runtime: 137 seconds.
# #### Starting deep BSDE method with seed 1 - 2 out of 10 times
# Time taken: 724 seconds; L1 error: 6.63E-03; L2 error: 5.46E-05; rel error: 4.26E-02.
#
#
# #### Starting deep branching method with seed 2 - 3 out of 10 times
# Time taken: 1099 seconds; L1 error: 1.26E-02; L2 error: 2.46E-04; rel error: 4.41E-02.
# total runtime: 1099 seconds.
# #### Starting NPP23 beep branching method with seed 2 - 3 out of 10 times
# Time taken: 142 seconds; L1 error: 1.35E-02; L2 error: 2.58E-04; rel error: 3.90E-02.
# fdb runtime: 0 seconds; total runtime: 142 seconds.
# #### Starting deep BSDE method with seed 2 - 3 out of 10 times
# Time taken: 720 seconds; L1 error: 1.05E+01; L2 error: 1.11E+02; rel error: 9.77E+01.
#
#
# #### Starting deep branching method with seed 3 - 4 out of 10 times
# Time taken: 1105 seconds; L1 error: 1.48E-02; L2 error: 3.83E-04; rel error: 3.89E-02.
# total runtime: 1105 seconds.
# #### Starting NPP23 beep branching method with seed 3 - 4 out of 10 times
# Time taken: 139 seconds; L1 error: 1.33E-02; L2 error: 2.44E-04; rel error: 4.29E-02.
# fdb runtime: 0 seconds; total runtime: 139 seconds.
# #### Starting deep BSDE method with seed 3 - 4 out of 10 times
# Time taken: 720 seconds; L1 error: 1.09E+01; L2 error: 1.21E+02; rel error: 1.04E+02.
#
#
# #### Starting deep branching method with seed 4 - 5 out of 10 times
# Time taken: 1103 seconds; L1 error: 1.28E-02; L2 error: 2.41E-04; rel error: 3.84E-02.
# total runtime: 1103 seconds.
# #### Starting NPP23 beep branching method with seed 4 - 5 out of 10 times
# Time taken: 130 seconds; L1 error: 1.57E-02; L2 error: 5.72E-04; rel error: 4.02E-02.
# fdb runtime: 0 seconds; total runtime: 130 seconds.
# #### Starting deep BSDE method with seed 4 - 5 out of 10 times
# Time taken: 720 seconds; L1 error: 1.11E+01; L2 error: 1.24E+02; rel error: 1.02E+02.
#
#
# #### Starting deep branching method with seed 5 - 6 out of 10 times
# Time taken: 1146 seconds; L1 error: 1.37E-02; L2 error: 2.78E-04; rel error: 4.49E-02.
# total runtime: 1146 seconds.
# #### Starting NPP23 beep branching method with seed 5 - 6 out of 10 times
# Time taken: 137 seconds; L1 error: 1.33E-02; L2 error: 2.46E-04; rel error: 4.24E-02.
# fdb runtime: 0 seconds; total runtime: 137 seconds.
# #### Starting deep BSDE method with seed 5 - 6 out of 10 times
# Time taken: 725 seconds; L1 error: 9.43E-03; L2 error: 1.55E-04; rel error: 1.58E-01.
#
#
# #### Starting deep branching method with seed 6 - 7 out of 10 times
# Time taken: 1078 seconds; L1 error: 1.35E-02; L2 error: 2.78E-04; rel error: 3.97E-02.
# total runtime: 1078 seconds.
# #### Starting NPP23 beep branching method with seed 6 - 7 out of 10 times
# Time taken: 132 seconds; L1 error: 1.17E-02; L2 error: 2.06E-04; rel error: 3.40E-02.
# fdb runtime: 0 seconds; total runtime: 132 seconds.
# #### Starting deep BSDE method with seed 6 - 7 out of 10 times
# Time taken: 720 seconds; L1 error: 1.52E+01; L2 error: 2.31E+02; rel error: 1.23E+02.
#
#
# #### Starting deep branching method with seed 7 - 8 out of 10 times
# Time taken: 1090 seconds; L1 error: 1.28E-02; L2 error: 2.26E-04; rel error: 4.59E-02.
# total runtime: 1090 seconds.
# #### Starting NPP23 beep branching method with seed 7 - 8 out of 10 times
# Time taken: 146 seconds; L1 error: 1.32E-02; L2 error: 2.45E-04; rel error: 4.28E-02.
# fdb runtime: 0 seconds; total runtime: 146 seconds.
# #### Starting deep BSDE method with seed 7 - 8 out of 10 times
# Time taken: 725 seconds; L1 error: 5.59E-03; L2 error: 5.22E-05; rel error: 3.14E-02.
#
#
# #### Starting deep branching method with seed 8 - 9 out of 10 times
# Time taken: 1064 seconds; L1 error: 1.29E-02; L2 error: 2.41E-04; rel error: 4.14E-02.
# total runtime: 1064 seconds.
# #### Starting NPP23 beep branching method with seed 8 - 9 out of 10 times
# Time taken: 135 seconds; L1 error: 1.26E-02; L2 error: 2.24E-04; rel error: 4.09E-02.
# fdb runtime: 0 seconds; total runtime: 135 seconds.
# #### Starting deep BSDE method with seed 8 - 9 out of 10 times
# Time taken: 722 seconds; L1 error: 1.38E+01; L2 error: 1.91E+02; rel error: 1.30E+02.
#
#
# #### Starting deep branching method with seed 9 - 10 out of 10 times
# Time taken: 1055 seconds; L1 error: 1.35E-02; L2 error: 3.36E-04; rel error: 3.77E-02.
# total runtime: 1055 seconds.
# #### Starting NPP23 beep branching method with seed 9 - 10 out of 10 times
# Time taken: 134 seconds; L1 error: 1.27E-02; L2 error: 2.31E-04; rel error: 4.00E-02.
# fdb runtime: 0 seconds; total runtime: 134 seconds.
# #### Starting deep BSDE method with seed 9 - 10 out of 10 times
# Time taken: 725 seconds; L1 error: 6.53E-03; L2 error: 6.02E-05; rel error: 6.65E-02.
#
#
#
#
# ######## Summary for deep branching method
# runtime:        1093
# total runtime:  1093
# mean L1 error:  1.33E-02
# std L1 error:   6.36E-04
# mean L2 error:  2.73E-04
# std L2 error:   4.74E-05
# mean rel error: 4.12E-02
# std rel error:  2.90E-03
#
#
# ######## Summary for NPP23 deep branching method
# runtime:        137
# fdb runtime:    0
# total runtime:  137
# mean L1 error:  1.32E-02
# std L1 error:   9.77E-04
# mean L2 error:  2.72E-04
# std L2 error:   1.01E-04
# mean rel error: 4.04E-02
# std rel error:  2.71E-03
#
#
# ######## Summary for deep BSDE method
# runtime:        723
# mean L1 error:  6.14E+00
# std L1 error:   6.28E+00
# mean L2 error:  7.79E+01
# std L2 error:   8.48E+01
# mean rel error: 5.57E+01
# std rel error:  5.63E+01
